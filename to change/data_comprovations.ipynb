# %%
import os, csv, re
from typing import Dict, Iterable, Set, List, Tuple
from collections import Counter, defaultdict
from itertools import combinations
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
BASE = os.path.join(os.path.dirname(os.path.abspath("")), ".src", "gtfs", "data")
PATHWAYS_FILE   = os.path.join(BASE, "pathways.txt")
TRANSFERS_FILE  = os.path.join(BASE, "transfers.txt")
STOPS_FILE      = os.path.join(BASE, "stops.txt")
STOP_TIMES_FILE = os.path.join(BASE, "stop_times.txt")
STOP_TIMES_CLEANED_FILE = os.path.join(BASE, "stop_times_cleaned.txt")
TRIPS_FILE      = os.path.join(BASE, "trips.txt")
ROUTES_FILE     = os.path.join(BASE, "routes.txt")

# %%
def check_missing_files(list_of_files: List[str]) -> None:
    '''Prints files that were not found.'''
    missing_files = [p for p in list_of_files if not os.path.exists(p)]
    if missing_files:
        print("The following files were not found:")
        for p in missing_files:
            print(" -", p)
    return

# %%
def sniff_dialect(file_path: str) -> csv.Dialect:
    '''Automatically detects the CSV separator and returns a dialect; falls back to comma by default.'''
    try:
        with open(file_path, 'r', encoding='utf-8-sig', newline='') as f:
            sample = f.read(65536)
        return csv.Sniffer().sniff(sample, delimiters=",;\t")
    except Exception:
        class _D(csv.Dialect):
            delimiter = ','
            quotechar = '"'
            doublequote = True
            skipinitialspace = False
            lineterminator = '\n'
            quoting = csv.QUOTE_MINIMAL
        return _D

# %%
def read_dict_rows(file_path: str) -> Iterable[Dict[str, str]]:
    '''Reads the CSV (auto dialect) and returns rows as dicts with lowercase keys and stripped values.'''
    dialect = sniff_dialect(file_path)
    with open(file_path, 'r', encoding='utf-8-sig', newline='') as f:
        reader = csv.DictReader(f, dialect=dialect)
        if reader.fieldnames is None:
            raise RuntimeError(f"The file {os.path.basename(file_path)} has no header.")
        fn_map = {name: name.lower().strip() for name in reader.fieldnames}
        for row in reader:
            out = {}
            for k, v in row.items():
                lk = fn_map.get(k, k).lower()
                sv = (v if v is not None else '').strip()
                out[lk] = sv
            yield out

# %%
def get_first_nonempty(row: Dict[str, str], *names: str) -> str:
    '''Returns the first non-empty value from the given field names.'''
    for n in names:
        v = row.get(n, '').strip()
        if v:
            return v
    return ''

# %%
def load_stop_ids(file_path: str) -> List[str]:
    '''Loads all stop_id from the file as a list.'''
    ids: List[str] = []
    for r in read_dict_rows(file_path):
        sid = r.get('stop_id', '').strip()
        if sid:
            ids.append(sid)
    return ids

# %%
def load_stop_names(file_path: str) -> Dict[str, str]:
    """Returns a map of stop_id -> stop_name."""
    names: Dict[str, str] = {}
    for r in read_dict_rows(file_path):
        sid = r.get('stop_id', '').strip()
        sname = r.get('stop_name', '').strip()
        if sid:
            names[sid] = sname
    return names

# %%
def load_pathway_ids(file_path: str) -> Set[str]:
    '''Returns the set of pathway_id from the file.'''
    ids: Set[str] = set()
    for r in read_dict_rows(file_path):
        pid = r.get('pathway_id', '').strip()
        if pid:
            ids.add(pid)
    return ids

# %%
def load_route_ids(file_path: str) -> Set[str]:
    '''Returns the set of route_id.'''
    ids: Set[str] = set()
    for r in read_dict_rows(file_path):
        rid = r.get('route_id', '').strip()
        if rid:
            ids.add(rid)
    return ids

# %%
def load_trip_ids(file_path: str) -> Set[str]:
    '''Returns the set of trip_id from the file.'''
    ids: Set[str] = set()
    for r in read_dict_rows(file_path):
        tid = r.get('trip_id', '').strip()
        if tid:
            ids.add(tid)
    return ids

# %%
def load_stop_ids(file_path: str) -> Set[str]:
    '''Returns the set of stop_id from the file.'''
    ids: Set[str] = set()
    for r in read_dict_rows(file_path):
        tid = r.get('stop_id', '').strip()
        if tid:
            ids.add(tid)
    return ids

# %%
def load_from_stop_ids(file_path: str) -> Set[str]:
    '''Returns the set of from_stop_id from the file.'''
    ids: Set[str] = set()
    for r in read_dict_rows(file_path):
        tid = r.get('from_stop_id', '').strip()
        if tid:
            ids.add(tid)
    return ids

# %%
def load_to_stop_ids(file_path: str) -> Set[str]:
    '''Returns the set of to_stop_id from the file.'''
    ids: Set[str] = set()
    for r in read_dict_rows(file_path):
        tid = r.get('to_stop_id', '').strip()
        if tid:
            ids.add(tid)
    return ids

# %%
def check_trip(trip_id: str, seqs_sorted: List[int]) -> List[str]:
    '''Checks that the stop_sequence values of a trip_id are consecutive. Returns
    error messages.'''
    msgs: List[str] = []
    last_seq = None
    for seq in seqs_sorted:
        if last_seq is not None and seq != last_seq + 1:
            msgs.append(
                f"Trip_id {trip_id}: stop_sequence does not increment by one ({last_seq} -> {seq})"
            )
        last_seq = seq
    return msgs

# %%
def make_signature(item: Tuple[str, List[Tuple[int, str, str]]]) -> Tuple[str, Tuple[Tuple[int, str, str], ...]]:
    """
    Builds a canonical signature for a trip_id from its
    sequence of events (stop_sequence, arrival_time, departure_time),
    sorted by stop_sequence (int). Returns (trip_id, signature).
    """
    trip_id, rows = item
    normalized = tuple(sorted(rows, key=lambda x: x[0]))
    return trip_id, normalized

# %% [markdown]
# ### File connection checks

# %% [markdown]
# #### All stop_id from pathways and stop_times exist in stops

# %%
def main():
    check_missing_files([PATHWAYS_FILE, STOP_TIMES_FILE, STOPS_FILE])

    pathways_from_stop_ids = load_from_stop_ids(PATHWAYS_FILE)
    pathways_to_stop_ids = load_to_stop_ids(PATHWAYS_FILE)
    stop_times_stop_ids = load_stop_ids(STOP_TIMES_FILE)
    stops_stop_ids = load_stop_ids(STOPS_FILE)

    missing_pathways_from = sorted(ids for ids in pathways_from_stop_ids if ids not in stops_stop_ids)
    missing_pathways_to = sorted(ids for ids in pathways_to_stop_ids if ids not in stops_stop_ids)
    missing_stop_times = sorted(ids for ids in stop_times_stop_ids if ids not in stops_stop_ids)

    if not missing_pathways_from:
        print(" - All correct: no from_stop_id from pathways.txt is missing in stops.txt")
    else:
        print(f" - MISSING {len(missing_pathways_from)} from_stop_id from pathways.txt in stops.txt:")
        for sid in missing_pathways_from:
            print("   -", sid)
    if not missing_pathways_to:
        print(" - All correct: no to_stop_id from pathways.txt is missing in stops.txt")
    else:        
        print(f" - MISSING {len(missing_pathways_to)} to_stop_id from pathways.txt in stops.txt:")
        for sid in missing_pathways_to:
            print("   -", sid)
    if not missing_stop_times:
        print(" - All correct: no stop_id from stop_times.txt is missing in stops.txt")
    else:
        print(f" - MISSING {len(missing_stop_times)} stop_id from stop_times.txt in stops.txt:")
        for sid in missing_stop_times:
            print("   -", sid)

main()
# Out:
#  - All correct: no from_stop_id from pathways.txt is missing in stops.txt
#  - All correct: no to_stop_id from pathways.txt is missing in stops.txt
#  - All correct: no stop_id from stop_times.txt is missing in stops.txt

# %% [markdown]
# #### All route_id from trips exist in routes

# %%
def main():
    check_missing_files([TRIPS_FILE, ROUTES_FILE])

    trips_route_ids = load_route_ids(TRIPS_FILE)
    routes_route_ids = load_route_ids(ROUTES_FILE)

    missing = sorted(ids for ids in trips_route_ids if ids not in routes_route_ids)

    print(f"Unique route_id in trips: {len(trips_route_ids)}")
    print(f"Unique route_id in routes: {len(routes_route_ids)}")

    if not missing:
        print("All correct: all route_id present in trips also appear in routes.")
    else:
        print(f"MISSING {len(missing)} route_id (present in trips but not in routes):")
        for rid in missing:
            print(f"- {rid}")

main()
# Out:
# Unique route_id in trips: 114
# Unique route_id in routes: 114
# All correct: all route_id present in trips also appear in routes.

# %% [markdown]
# #### All trip_id from stop_times exist in trips

# %%
def main():
    check_missing_files([STOP_TIMES_FILE, TRIPS_FILE])

    stop_times_trip_ids = load_trip_ids(STOP_TIMES_FILE)
    trips_trip_ids = load_trip_ids(TRIPS_FILE)

    missing= sorted(ids for ids in stop_times_trip_ids if ids not in trips_trip_ids)    

    print(f"Unique trip_id in stop_times: {len(stop_times_trip_ids)}")
    print(f"Unique trip_id in trips: {len(trips_trip_ids)}")

    if not missing:
        print("All correct: all trip_id present in stop_times also appear in trips.")    
    else:
        print(f"MISSING {len(missing)} trip_id (present in stop_times but not in trips):")
        for tid in missing:
            print(f"- {tid}")

main()
# Out:
# Unique trip_id in stop_times: 48987
# Unique trip_id in trips: 48987
# All correct: all trip_id present in stop_times also appear in trips.

# %% [markdown]
# ### Check that transfers are within pathways

# %% [markdown]
# Check that each (from_stop_id, to_stop_id) from transfers has a pathway_id = "PW.{from_stop_id}_{to_stop_id}" in pathways

# %%
def load_transfer_pairs(file_path: str) -> Iterable[Tuple[str, str]]:
    '''Generates (from_stop_id, to_stop_id) pairs from transfers.txt.'''
    for r in read_dict_rows(file_path):
        a = r.get('from_stop_id', '').strip()
        b = r.get('to_stop_id', '').strip()
        if a or b:
            yield a, b

# %%
def main() -> None:
    check_missing_files([PATHWAYS_FILE, TRANSFERS_FILE])

    pathways_ids = load_pathway_ids(PATHWAYS_FILE)
    transfers_pairs = list(load_transfer_pairs(TRANSFERS_FILE))

    expected_ids = [f"PW.{a}_{b}" for a, b in transfers_pairs]
    missing = [(a, b, eid) for (a, b), eid in zip(transfers_pairs, expected_ids) if eid not in pathways_ids]

    print(f"Total transfers: {len(transfers_pairs)}")
    print(f"Total pathways: {len(pathways_ids)}")

    if not missing:
        print("All correct: all rows in transfers have a corresponding pathway (format 'PW.{from_stop_id}_{to_stop_id}').")
    else:
        print(f"MISSING {len(missing)} pathways for specific transfers (showing all):")
        for a, b, eid in missing:
            print(f"- from_stop_id={a!r}, to_stop_id={b!r} -> expected pathway_id={eid!r}")


main()
# Out:
# Total transfers: 60
# Total pathways: 1063
# All correct: all rows in transfers have a corresponding pathway (format 'PW.{from_stop_id}_{to_stop_id}').

# %% [markdown]
# ### Check that pathways have both directions

# %% [markdown]
# Check symmetry in pathways: for each PW.x_y check that PW.y_x exists.
# When the inverse is missing, show the stop_name and coordinates (lat/lon) for each a and b.

# %%
# Only pathways with prefix 'PW.' and exactly two parts separated by '_'
PW_PAIR = re.compile(r'^PW\.(?P<a>[^_]+)_(?P<b>[^\s]+)$')

# %%
def main() -> None:
    check_missing_files([PATHWAYS_FILE, STOPS_FILE])
    
    pids = load_pathway_ids(PATHWAYS_FILE)

    # Load stop info: name and coordinates
    stops_info: Dict[str, Tuple[str, str, str]] = {}
    for r in read_dict_rows(STOPS_FILE):
        sid = r.get('stop_id', '').strip()
        if not sid:
            continue
        name = r.get('stop_name', '').strip()
        lat = r.get('stop_lat', '').strip()
        lon = r.get('stop_lon', '').strip()
        stops_info[sid] = (name, lat, lon)

    # Consider only those following the format 'PW.a_b'
    candidate_pids = {pid for pid in pids if PW_PAIR.match(pid) is not None}

    missing: List[Tuple[str, str, str, str]] = []
    for pid in sorted(candidate_pids):
        m = PW_PAIR.match(pid)
        a, b = m.group('a'), m.group('b')
        reverse_id = f"PW.{b}_{a}"
        if reverse_id not in pids:
            missing.append((pid, reverse_id, a, b))

    print(f"Total pathways: {len(pids)}")
    print(f"Candidates with format 'PW.a_b': {len(candidate_pids)}")

    if not missing:
        print("All correct: for each pathway 'PW.x_y' there also exists 'PW.y_x'.")
    else:
        print(f"MISSING {len(missing)} inverse pathways (showing all):")
        for pid, rid, a, b in missing:
            print(f"- Exists {pid!r} but missing its inverse {rid!r}")
            a_name, a_lat, a_lon = stops_info.get(a, ("(no name)", "", ""))
            b_name, b_lat, b_lon = stops_info.get(b, ("(no name)", "", ""))
            print(f"  · {a} — {a_name} (lat={a_lat}, lon={a_lon})")
            print(f"  · {b} — {b_name} (lat={b_lat}, lon={b_lon})")

main()
# Out:
# Total pathways: 1063
# Candidates with format 'PW.a_b': 1063
# MISSING 1 inverse pathways (showing all):
# - Exists 'PW.1.120_E.12001' but missing its inverse 'PW.E.12001_1.120'
#   · 1.120 — Plaça de Sants (lat=41.375353, lon=2.138154)
#   · E.12001 — Alcolea (escala mecànica) (lat=41.375457, lon=2.137077)

# %% [markdown]
# ### Check that each entrance is connected to a platform

# %% [markdown]
# Check that each stop_id starting with 'E.' has at least one pathway with a platform '1.'
# Requirement: pathway_id of the type 'PW.E.xxx_1.yyy' or 'PW.1.yyy_E.xxx'

# %%
def main():
    check_missing_files([PATHWAYS_FILE, STOPS_FILE])

    e_stops_info: Dict[str, Tuple[str, str, str]] = {}
    for r in read_dict_rows(STOPS_FILE):
        sid = r.get('stop_id', '').strip()
        if not sid or not sid.startswith('E.'):
            continue
        name = r.get('stop_name', '').strip()
        lat = r.get('stop_lat', '').strip()
        lon = r.get('stop_lon', '').strip()
        e_stops_info[sid] = (name, lat, lon)

    pids = load_pathway_ids(PATHWAYS_FILE)

    # E.* with at least one PW connection to some 1.* (in any order)
    covered: Set[str] = set()
    for pid in pids:
        m = PW_PAIR.match(pid)
        if not m:
            continue
        a, b = m.group('a'), m.group('b')
        if a.startswith('E.') and b.startswith('1.'):
            covered.add(a)
        elif b.startswith('E.') and a.startswith('1.'):
            covered.add(b)

    missing = [e for e in e_stops_info.keys() if e not in covered]

    print(f"Entrances (E.*): {len(e_stops_info)}")
    print(f"Entrances with at least one pathway to a platform (1.*): {len(covered)}")

    if not missing:
        print("All correct: each E.* has at least one pathway 'PW.E.xxx_1.yyy' or 'PW.1.yyy_E.xxx'.")
    else:
        print(f"MISSING {len(missing)} E.* without any pathway to 1.* (showing all):")
        for e in missing:
            name, lat, lon = e_stops_info.get(e, ("(no name)", "", ""))
            print(f"- {e} — {name} (lat={lat}, lon={lon})")

main()
# Out:
# Entrances (E.*): 502
# Entrances with at least one pathway to a platform (1.*): 502
# All correct: each E.* has at least one pathway 'PW.E.xxx_1.yyy' or 'PW.1.yyy_E.xxx'.

# %% [markdown]
# ### Check that each platform is connected to an entrance

# %% [markdown]
# Check that each stop_id starting with '1.' (platform) has at least one pathway with an entrance 'E.'
# That is, check if there exists some 'PW.1.xxx_E.yyy' or 'PW.E.yyy_1.xxx' for each '1.xxx'.
# When one is missing, also show the associated stop_name and suggest a neighboring platform (1.*) that does have an entrance, with its entrance (E.*) and names.

# %%
def build_graph_and_coverage(pids: Set[str]) -> Tuple[Dict[str, Set[str]], Dict[str, Set[str]], Set[str]]:
    """Builds:
    - adj_1: adjacency graph only between platforms 1.* (1.xxx <-> 1.yyy)
    - one_to_entries: map 1.xxx -> set of entrances E.* connected via pathway
    - covered: set of platforms 1.* that have at least one entrance E.*
    """
    adj_1: Dict[str, Set[str]] = {}
    one_to_entries: Dict[str, Set[str]] = {}
    covered: Set[str] = set()

    def add_edge_1(u: str, v: str):
        if u not in adj_1:
            adj_1[u] = set()
        if v not in adj_1:
            adj_1[v] = set()
        adj_1[u].add(v)
        adj_1[v].add(u)

    def add_entry(u: str, e: str):
        if u not in one_to_entries:
            one_to_entries[u] = set()
        one_to_entries[u].add(e)
        covered.add(u)

    for pid in pids:
        m = PW_PAIR.match(pid)
        if not m:
            continue
        a, b = m.group('a'), m.group('b')

        # Links between platforms
        if a.startswith('1.') and b.startswith('1.'):
            add_edge_1(a, b)
            
        # Platform-entrance links
        if a.startswith('1.') and b.startswith('E.'):
            add_entry(a, b)
        elif b.startswith('1.') and a.startswith('E.'):
            add_entry(b, a)

    return adj_1, one_to_entries, covered

# %%
def main():
    check_missing_files([PATHWAYS_FILE, STOPS_FILE])

    stop_ids = load_stop_ids(STOPS_FILE)
    stop_names = load_stop_names(STOPS_FILE)
    one_stops = sorted({s for s in stop_ids if s.startswith('1.')})

    pids = load_pathway_ids(PATHWAYS_FILE)

    # Platform graph and entrance coverage
    adj_1, one_to_entries, covered = build_graph_and_coverage(pids)

    missing = [s for s in one_stops if s not in covered]

    print(f"Total stops: {len(stop_ids)}")
    print(f"Platforms (1.*): {len(one_stops)}")
    print(f"Platforms with at least one pathway to an entrance (E.*): {len(covered)}")

    if not missing:
        print("All correct: each 1.* has at least one pathway 'PW.1.xxx_E.yyy' or 'PW.E.yyy_1.xxx'.")
        return

    print(f"MISSING {len(missing)} 1.* without any pathway to E.* (showing all):")
    for s in missing:
        nom = stop_names.get(s, "(no name)")
        print(f"- {s} — {nom}")
        # Suggest neighboring platforms that do have an entrance
        neigh = sorted(adj_1.get(s, []))
        sugg = [n for n in neigh if n in one_to_entries and one_to_entries[n]]
        if sugg:
            print("    Connected to platforms that do have at least one entrance:")
            for n in sugg:
                n_nom = stop_names.get(n, "(no name)")
                # Pick one entrance (or all)
                entries = sorted(one_to_entries[n])
                # Show one (the first) for simplicity
                e = entries[0]
                e_nom = stop_names.get(e, "(no name)")
                print(f"    · {n} — {n_nom} -> entrance {e} — {e_nom}")
        else:
            print("    (Not connected to any platform 1.* that has an entrance E.*)")

main()
# Out:
# Total stops: 3443
# Platforms (1.*): 165
# Platforms with at least one pathway to an entrance (E.*): 158
# MISSING 7 1.* without any pathway to E.* (showing all):
# - 1.1136 — Trinitat Nova
#     Connected to platforms that do have at least one entrance:
#     · 1.339 — Trinitat Nova -> entrance E.33901 — Palamós
#     · 1.434 — Trinitat Nova -> entrance E.43401 — Pedrosa
# - 1.221 — La Pau
#     Connected to platforms that do have at least one entrance:
#     · 1.413 — La Pau -> entrance E.1041301 — Ascensor - Rambla Guipúscoa / Ca n'Oliva
# - 1.323 — Paral·lel
#     Connected to platforms that do have at least one entrance:
#     · 1.210 — Paral·lel -> entrance E.1021002 — Ascensor - Avinguda Paral·lel
# - 1.915 — Torrassa
#     Connected to platforms that do have at least one entrance:
#     · 1.117 — Torrassa -> entrance E.1011711 — Ascensor - Av. Catalunya
# - 1.930 — La Sagrera
#     Connected to platforms that do have at least one entrance:
#     · 1.133 — La Sagrera -> entrance E.1013301 — Ascensor - Meridiana | Hondures
#     · 1.526 — La Sagrera -> entrance E.1052611 — Ascensor - Felip II
# - 1.942 — Fondo
#     Connected to platforms that do have at least one entrance:
#     · 1.140 — Fondo -> entrance E.1014002 — Ascensor - Mossèn Cinto Verdaguer
# - 1.9901 — Paral·lel
#     Connected to platforms that do have at least one entrance:
#     · 1.210 — Paral·lel -> entrance E.1021002 — Ascensor - Avinguda Paral·lel

# %% [markdown]
# ### Check that there is a pathway between platforms of the same stop

# %% [markdown]
# Check that all platforms (1.*) with the same stop_name have pathways between each pair. Example: if 1.339, 1.434 and 1.1136 exist with the same name, pathways are needed between each pair (we only check one direction per pair; reciprocity is already validated in a previous cell).

# %%
def load_platforms_by_name(file_path: str) -> Dict[str, List[str]]:
    """Returns name_to_ones: map stop_name -> list of platforms (1.*) with the same name"""
    name_to_ones: Dict[str, List[str]] = {}
    for r in read_dict_rows(file_path):
        sid = r.get('stop_id', '').strip()
        sname = r.get('stop_name', '').strip()
        if not sid:
            continue
        if sid.startswith('1.'):
            name_to_ones.setdefault(sname, []).append(sid)
    # Sort lists and remove duplicates
    for k in list(name_to_ones.keys()):
        name_to_ones[k] = sorted(set(name_to_ones[k]))
    return name_to_ones

# %%
def load_platform_pairs_present(file_path: str) -> Set[Tuple[str, str]]:
    """Returns pairs of platforms (1.*) that already have a pathway between them (in any order).
    Records pairs as lexicographically sorted tuples.
    Accepts pathway_id prefixed with 'PW.' and format 'PW.a_b'."""
    pair_pat = re.compile(r'^PW\.(?P<a>[^_]+)_(?P<b>[^_]+)$')
    pairs: Set[Tuple[str, str]] = set()
    for r in read_dict_rows(file_path):
        pid = r.get('pathway_id', '').strip()
        if not pid:
            continue
        m = pair_pat.match(pid)
        if not m:
            continue
        a, b = m.group('a'), m.group('b')
        if a.startswith('1.') and b.startswith('1.'):
            u, v = sorted((a, b))
            pairs.add((u, v))
    return pairs

# %%
def main():
    check_missing_files([PATHWAYS_FILE, STOPS_FILE])

    name_to_ones = load_platforms_by_name(STOPS_FILE)
    platform_pairs = load_platform_pairs_present(PATHWAYS_FILE)

    # Basic statistics
    total_ones = sum(len(v) for v in name_to_ones.values())
    groups_multi = {name: ids for name, ids in name_to_ones.items() if len(ids) >= 2}

    print(f"Total platforms (1.*): {total_ones}")
    print(f"Stops with multiple platforms (same name): {len(groups_multi)}")

    # Check all combinations per group
    missing: List[Tuple[str, str, str]] = []  # (name, u, v)
    for name, ids in sorted(groups_multi.items()):
        for u, v in combinations(sorted(ids), 2):
            if (u, v) not in platform_pairs:
                missing.append((name, u, v))

    if not missing:
        print("All correct: for each stop with multiple platforms, there are pathways between all platform pairs.")
    else:
        print(f"MISSING pathways between {len(missing)} platform pairs within the same stop (showing all):")
        for name, u, v in missing:
            print(f"- {name}: missing pathway between {u} and {v}")

main()
# Out:
# Total platforms (1.*): 165
# Stops with multiple platforms (same name): 22
# All correct: for each stop with multiple platforms, there are pathways between all platform pairs.

# %% [markdown]
# ### stop_times checks

# %% [markdown]
# #### Duplicate full trip_id in stop_times

# %%
def main():
    check_missing_files([STOP_TIMES_FILE, TRIPS_FILE])

    # trip_id of interest (filtered by prefix '1.')
    trip_ids = load_trip_ids(TRIPS_FILE)
    trip_ids = sorted(ids for ids in trip_ids if ids.startswith("1."))
    trip_id_set = set(trip_ids)

    print(f"Unique trip_id in trips (prefix '1.'): {len(trip_ids)}")

    # Aggregate all stop_times rows per trip_id
    # Store tuples (stop_sequence_int, arrival_time, departure_time, stop_id)
    trips_rows: Dict[str, List[Tuple[int, str, str, str]]] = defaultdict(list)
    total_rows = 0
    for r in read_dict_rows(STOP_TIMES_FILE):
        total_rows += 1
        tid = r.get('trip_id', '')
        if tid not in trip_id_set:
            continue
        seq_s = r.get('stop_sequence', '')
        arr = r.get('arrival_time', '')
        dep = r.get('departure_time', '')
        sid = r.get('stop_id', '')
        try:
            seq = int(seq_s)
        except Exception:
            seq = 10**9
        trips_rows[tid].append((seq, arr, dep, sid))

    print(f"Total rows read from stop_times: {total_rows}")
    print(f"trip_id with at least one row in stop_times: {len(trips_rows)}")

    # Build signatures in parallel for each trip_id
    sig_to_trips: Dict[Tuple[Tuple[int, str, str, str], ...], List[str]] = defaultdict(list)
    max_workers = min(8, (os.cpu_count() or 4))
    with ThreadPoolExecutor(max_workers=max_workers) as ex:
        futures = {ex.submit(make_signature, item): item[0] for item in trips_rows.items()}
        for fut in as_completed(futures):
            tid, sig = fut.result()
            sig_to_trips[sig].append(tid)

    # Duplicate groups: signatures shared by >= 2 different trip_id
    duplicate_groups = [(sig, sorted(tids)) for sig, tids in sig_to_trips.items() if len(tids) >= 2]
    duplicate_groups.sort(key=lambda x: (len(x[1]), x[1]))

    if not duplicate_groups:
        print("No pair/group of trip_id with identical sequence and schedules was found.")
        return

    total_dup_trips = sum(len(tids) for _, tids in duplicate_groups)
    print(f"\nFound {len(duplicate_groups)} groups of trip_id with identical content ({total_dup_trips} trip_id in total).")

    len_counts = {}
    for _, tids in duplicate_groups:
        count = len(tids)
        len_counts[count] = len_counts.get(count, 0) + 1
    for count in sorted(len_counts.keys()):
        print(f"Groups with {count} trip_id: {len_counts[count]}")
        for sig, tids in duplicate_groups:
            if len(tids) == count:
                print(f"  Example group with {count} trip_id: {tids[:5]}{'...' if len(tids) > 5 else ''}")
                break

    # ---- Generate file with trip_id to eliminate ----
    # For each group, keep the first trip_id (alphabetically) and eliminate the rest
    to_eliminate: List[str] = []
    for _, tids in duplicate_groups:
        to_eliminate.extend(tids[1:])  # tids is already sorted

    out_path = os.path.join(BASE, "trip_ids_to_eliminate.txt")
    with open(out_path, "w", encoding="utf-8") as f:
        for tid in sorted(to_eliminate):
            f.write(tid + "\n")

    kept = total_dup_trips - len(to_eliminate)
    print(f"\nTrip_id kept from groups (1 per group): {kept}")
    print(f"Trip_id to eliminate: {len(to_eliminate)}")
    print(f"Total valid trip_id after removing duplicates: {len(trip_ids) - len(to_eliminate)}")
    print(f"Generated file: {out_path}")

    # ---- Group details ----
    for idx, (sig, tids) in enumerate(duplicate_groups, 1):
        print(f"\nGroup {idx}: {len(tids)} trip_id  (kept: {tids[0]})")
        for t in tids[1:]:
            print(f"  x {t}")
        print("Common content (sorted by stop_sequence):")
        limit = 100
        for i, (seq, arr, dep, sid) in enumerate(sig[:limit], 1):
            arr_show = arr if arr else "(none)"
            dep_show = dep if dep else "(none)"
            sid_show = sid if sid else "(none)"
            print(f"  {i:02d}. seq={seq}, arrival={arr_show}, departure={dep_show}, stop_id={sid_show}")
        if len(sig) > limit:
            print(f"  ... ({len(sig) - limit} more lines)")

main()
# Out:
# Unique trip_id in trips (prefix '1.'): 15088
# Total rows read from stop_times: 1138586
# trip_id with at least one row in stop_times: 15088
#
# Found 4085 groups of trip_id with identical content (8196 trip_id in total).
# Groups with 2 trip_id: 4065
#   Example group with 2 trip_id: ['1.1.11654310', '1.1.11655306']
# Groups with 3 trip_id: 14
#   Example group with 3 trip_id: ['1.101.11427287', '1.101.11427796', '1.101.11428435']
# Groups with 4 trip_id: 6
#   Example group with 4 trip_id: ['1.104.11428897', '1.104.11430235', '1.104.11571861', '1.104.11572496']
#
# Trip_id kept from groups (1 per group): 4085
# Trip_id to eliminate: 4111
# Total valid trip_id after removing duplicates: 10977
# Generated file: c:\Users\Sarad\Escritorio\Mates\Cursos\Curs 2025-2026 (3r + 4t)\TFG\TFG\.src\gtfs\data\trip_ids_to_eliminate.txt
#
# Group 1: 2 trip_id  (kept: 1.1.11654310)
#   x 1.1.11655306
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.111
#   02. seq=2, arrival=05:01:26, departure=05:01:48, stop_id=1.112
#   03. seq=3, arrival=05:03:27, departure=05:03:49, stop_id=1.113
#   04. seq=4, arrival=05:04:58, departure=05:05:17, stop_id=1.114
#   05. seq=5, arrival=05:06:19, departure=05:06:38, stop_id=1.115
#   06. seq=6, arrival=05:07:41, departure=05:08:00, stop_id=1.116
#   07. seq=7, arrival=05:09:01, departure=05:09:23, stop_id=1.117
#   08. seq=8, arrival=05:10:54, departure=05:11:26, stop_id=1.118
#   09. seq=9, arrival=05:12:43, departure=05:13:02, stop_id=1.119
#   10. seq=10, arrival=05:14:04, departure=05:14:26, stop_id=1.120
#   11. seq=11, arrival=05:15:18, departure=05:15:37, stop_id=1.121
#   12. seq=12, arrival=05:16:36, departure=05:17:14, stop_id=1.122
#   13. seq=13, arrival=05:18:16, departure=05:18:38, stop_id=1.123
#   14. seq=14, arrival=05:19:35, departure=05:19:57, stop_id=1.124
#   15. seq=15, arrival=05:20:58, departure=05:21:20, stop_id=1.125
#   16. seq=16, arrival=05:22:15, departure=05:22:53, stop_id=1.126
#   17. seq=17, arrival=05:23:51, departure=05:24:13, stop_id=1.127
#   18. seq=18, arrival=05:25:21, departure=05:25:49, stop_id=1.128
#   19. seq=19, arrival=05:26:45, departure=05:27:07, stop_id=1.129
#   20. seq=20, arrival=05:28:28, departure=05:28:50, stop_id=1.130
#   21. seq=21, arrival=05:30:12, departure=05:30:40, stop_id=1.131
#   22. seq=22, arrival=05:31:48, departure=05:32:07, stop_id=1.132
#   23. seq=23, arrival=05:33:24, departure=05:34:02, stop_id=1.133
#   24. seq=24, arrival=05:35:32, departure=05:36:00, stop_id=1.134
#   25. seq=25, arrival=05:37:45, departure=05:38:07, stop_id=1.135
#   26. seq=26, arrival=05:39:17, departure=05:39:39, stop_id=1.136
#   27. seq=27, arrival=05:41:06, departure=05:41:25, stop_id=1.137
#   28. seq=28, arrival=05:42:33, departure=05:42:52, stop_id=1.138
#   29. seq=29, arrival=05:44:12, departure=05:44:34, stop_id=1.139
#   30. seq=30, arrival=05:45:57, departure=05:45:57, stop_id=1.140
#
# Group 2: 2 trip_id  (kept: 1.1.11654311)
#   x 1.1.11655307
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:52:04, departure=05:52:04, stop_id=1.140
#   02. seq=2, arrival=05:53:31, departure=05:53:49, stop_id=1.139
#   03. seq=3, arrival=05:55:13, departure=05:55:28, stop_id=1.138
#   04. seq=4, arrival=05:56:36, departure=05:56:51, stop_id=1.137
#   05. seq=5, arrival=05:58:11, departure=05:58:29, stop_id=1.136
#   06. seq=6, arrival=05:59:58, departure=06:00:23, stop_id=1.135
#   07. seq=7, arrival=06:02:04, departure=06:02:36, stop_id=1.134
#   08. seq=8, arrival=06:04:13, departure=06:04:56, stop_id=1.133
#   09. seq=9, arrival=06:06:09, departure=06:06:30, stop_id=1.132
#   10. seq=10, arrival=06:07:36, departure=06:08:08, stop_id=1.131
#   11. seq=11, arrival=06:09:30, departure=06:09:56, stop_id=1.130
#   12. seq=12, arrival=06:11:18, departure=06:11:44, stop_id=1.129
#   13. seq=13, arrival=06:12:39, departure=06:13:05, stop_id=1.128
#   14. seq=14, arrival=06:14:08, departure=06:14:34, stop_id=1.127
#   15. seq=15, arrival=06:15:34, departure=06:16:17, stop_id=1.126
#   16. seq=16, arrival=06:17:09, departure=06:17:35, stop_id=1.125
#   17. seq=17, arrival=06:18:53, departure=06:19:19, stop_id=1.124
#   18. seq=18, arrival=06:20:16, departure=06:20:42, stop_id=1.123
#   19. seq=19, arrival=06:21:47, departure=06:22:23, stop_id=1.122
#   20. seq=20, arrival=06:23:20, departure=06:23:41, stop_id=1.121
#   21. seq=21, arrival=06:24:33, departure=06:24:59, stop_id=1.120
#   22. seq=22, arrival=06:25:55, departure=06:26:16, stop_id=1.119
#   23. seq=23, arrival=06:27:29, departure=06:28:05, stop_id=1.118
#   24. seq=24, arrival=06:29:31, departure=06:29:57, stop_id=1.117
#   25. seq=25, arrival=06:30:57, departure=06:31:18, stop_id=1.116
#   26. seq=26, arrival=06:32:22, departure=06:32:43, stop_id=1.115
#   27. seq=27, arrival=06:33:44, departure=06:34:05, stop_id=1.114
#   28. seq=28, arrival=06:35:12, departure=06:35:38, stop_id=1.113
#   29. seq=29, arrival=06:37:18, departure=06:37:44, stop_id=1.112
#   30. seq=30, arrival=06:39:15, departure=06:39:15, stop_id=1.111
#
# Group 3: 2 trip_id  (kept: 1.1.11654312)
#   x 1.1.11655308
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=06:44:30, departure=06:44:30, stop_id=1.111
#   02. seq=2, arrival=06:45:56, departure=06:46:22, stop_id=1.112
#   03. seq=3, arrival=06:48:01, departure=06:48:27, stop_id=1.113
#   04. seq=4, arrival=06:49:36, departure=06:49:57, stop_id=1.114
#   05. seq=5, arrival=06:50:59, departure=06:51:20, stop_id=1.115
#   06. seq=6, arrival=06:52:23, departure=06:52:44, stop_id=1.116
#   07. seq=7, arrival=06:53:45, departure=06:54:11, stop_id=1.117
#   08. seq=8, arrival=06:55:42, departure=06:56:18, stop_id=1.118
#   09. seq=9, arrival=06:57:35, departure=06:57:56, stop_id=1.119
#   10. seq=10, arrival=06:58:58, departure=06:59:24, stop_id=1.120
#   11. seq=11, arrival=07:00:16, departure=07:00:37, stop_id=1.121
#   12. seq=12, arrival=07:01:36, departure=07:02:19, stop_id=1.122
#   13. seq=13, arrival=07:03:21, departure=07:03:47, stop_id=1.123
#   14. seq=14, arrival=07:04:44, departure=07:05:10, stop_id=1.124
#   15. seq=15, arrival=07:06:11, departure=07:06:37, stop_id=1.125
#   16. seq=16, arrival=07:07:32, departure=07:08:15, stop_id=1.126
#   17. seq=17, arrival=07:09:13, departure=07:09:39, stop_id=1.127
#   18. seq=18, arrival=07:10:47, departure=07:11:19, stop_id=1.128
#   19. seq=19, arrival=07:12:15, departure=07:12:41, stop_id=1.129
#   20. seq=20, arrival=07:14:02, departure=07:14:28, stop_id=1.130
#   21. seq=21, arrival=07:15:50, departure=07:16:22, stop_id=1.131
#   22. seq=22, arrival=07:17:30, departure=07:17:51, stop_id=1.132
#   23. seq=23, arrival=07:19:08, departure=07:19:51, stop_id=1.133
#   24. seq=24, arrival=07:21:21, departure=07:21:53, stop_id=1.134
#   25. seq=25, arrival=07:23:38, departure=07:24:04, stop_id=1.135
#   26. seq=26, arrival=07:25:14, departure=07:25:40, stop_id=1.136
#   27. seq=27, arrival=07:27:07, departure=07:27:28, stop_id=1.137
#   28. seq=28, arrival=07:28:36, departure=07:28:57, stop_id=1.138
#   29. seq=29, arrival=07:30:17, departure=07:30:43, stop_id=1.139
#   30. seq=30, arrival=07:32:06, departure=07:32:06, stop_id=1.140
#
# Group 4: 2 trip_id  (kept: 1.1.11654313)
#   x 1.1.11655309
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=07:36:54, departure=07:36:54, stop_id=1.140
#   02. seq=2, arrival=07:38:21, departure=07:38:47, stop_id=1.139
#   03. seq=3, arrival=07:40:11, departure=07:40:32, stop_id=1.138
#   04. seq=4, arrival=07:41:40, departure=07:42:01, stop_id=1.137
#   05. seq=5, arrival=07:43:21, departure=07:43:47, stop_id=1.136
#   06. seq=6, arrival=07:45:16, departure=07:45:42, stop_id=1.135
#   07. seq=7, arrival=07:47:23, departure=07:47:55, stop_id=1.134
#   08. seq=8, arrival=07:49:32, departure=07:50:15, stop_id=1.133
#   09. seq=9, arrival=07:51:28, departure=07:51:49, stop_id=1.132
#   10. seq=10, arrival=07:52:55, departure=07:53:27, stop_id=1.131
#   11. seq=11, arrival=07:54:49, departure=07:55:15, stop_id=1.130
#   12. seq=12, arrival=07:56:37, departure=07:57:03, stop_id=1.129
#   13. seq=13, arrival=07:57:58, departure=07:58:24, stop_id=1.128
#   14. seq=14, arrival=07:59:27, departure=07:59:53, stop_id=1.127
#   15. seq=15, arrival=08:00:53, departure=08:01:36, stop_id=1.126
#   16. seq=16, arrival=08:02:28, departure=08:02:54, stop_id=1.125
#   17. seq=17, arrival=08:04:12, departure=08:04:38, stop_id=1.124
#   18. seq=18, arrival=08:05:35, departure=08:06:01, stop_id=1.123
#   19. seq=19, arrival=08:07:06, departure=08:07:42, stop_id=1.122
#   20. seq=20, arrival=08:08:39, departure=08:09:00, stop_id=1.121
#   21. seq=21, arrival=08:09:52, departure=08:10:18, stop_id=1.120
#   22. seq=22, arrival=08:11:14, departure=08:11:35, stop_id=1.119
#   23. seq=23, arrival=08:12:48, departure=08:13:24, stop_id=1.118
#   24. seq=24, arrival=08:14:50, departure=08:15:16, stop_id=1.117
#   25. seq=25, arrival=08:16:16, departure=08:16:37, stop_id=1.116
#   26. seq=26, arrival=08:17:41, departure=08:18:02, stop_id=1.115
#   27. seq=27, arrival=08:19:03, departure=08:19:24, stop_id=1.114
#   28. seq=28, arrival=08:20:31, departure=08:20:57, stop_id=1.113
#   29. seq=29, arrival=08:22:37, departure=08:23:03, stop_id=1.112
#   30. seq=30, arrival=08:24:34, departure=08:24:34, stop_id=1.111
#
# Group 5: 2 trip_id  (kept: 1.1.11654314)
#   x 1.1.11655310
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=08:29:20, departure=08:29:20, stop_id=1.111
#   02. seq=2, arrival=08:30:46, departure=08:31:12, stop_id=1.112
#   03. seq=3, arrival=08:32:51, departure=08:33:17, stop_id=1.113
#   04. seq=4, arrival=08:34:26, departure=08:34:47, stop_id=1.114
#   05. seq=5, arrival=08:35:49, departure=08:36:10, stop_id=1.115
#   06. seq=6, arrival=08:37:13, departure=08:37:34, stop_id=1.116
#   07. seq=7, arrival=08:38:35, departure=08:39:01, stop_id=1.117
#   08. seq=8, arrival=08:40:32, departure=08:41:08, stop_id=1.118
#   09. seq=9, arrival=08:42:25, departure=08:42:46, stop_id=1.119
#   10. seq=10, arrival=08:43:48, departure=08:44:14, stop_id=1.120
#   11. seq=11, arrival=08:45:06, departure=08:45:27, stop_id=1.121
#   12. seq=12, arrival=08:46:26, departure=08:47:09, stop_id=1.122
#   13. seq=13, arrival=08:48:11, departure=08:48:37, stop_id=1.123
#   14. seq=14, arrival=08:49:34, departure=08:50:00, stop_id=1.124
#   15. seq=15, arrival=08:51:01, departure=08:51:27, stop_id=1.125
#   16. seq=16, arrival=08:52:22, departure=08:53:05, stop_id=1.126
#   17. seq=17, arrival=08:54:03, departure=08:54:29, stop_id=1.127
#   18. seq=18, arrival=08:55:37, departure=08:56:09, stop_id=1.128
#   19. seq=19, arrival=08:57:05, departure=08:57:31, stop_id=1.129
#   20. seq=20, arrival=08:58:52, departure=08:59:18, stop_id=1.130
#   21. seq=21, arrival=09:00:40, departure=09:01:12, stop_id=1.131
#   22. seq=22, arrival=09:02:20, departure=09:02:41, stop_id=1.132
#   23. seq=23, arrival=09:03:58, departure=09:04:41, stop_id=1.133
#   24. seq=24, arrival=09:06:11, departure=09:06:43, stop_id=1.134
#   25. seq=25, arrival=09:08:28, departure=09:08:54, stop_id=1.135
#   26. seq=26, arrival=09:10:04, departure=09:10:30, stop_id=1.136
#   27. seq=27, arrival=09:11:57, departure=09:12:18, stop_id=1.137
#   28. seq=28, arrival=09:13:26, departure=09:13:47, stop_id=1.138
#   29. seq=29, arrival=09:15:07, departure=09:15:33, stop_id=1.139
#   30. seq=30, arrival=09:16:56, departure=09:16:56, stop_id=1.140
#
# Group 6: 2 trip_id  (kept: 1.1.11654315)
#   x 1.1.11655311
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=09:21:44, departure=09:21:44, stop_id=1.140
#   02. seq=2, arrival=09:23:11, departure=09:23:37, stop_id=1.139
#   03. seq=3, arrival=09:25:01, departure=09:25:22, stop_id=1.138
#   04. seq=4, arrival=09:26:30, departure=09:26:51, stop_id=1.137
#   05. seq=5, arrival=09:28:11, departure=09:28:37, stop_id=1.136
#   06. seq=6, arrival=09:30:06, departure=09:30:32, stop_id=1.135
#   07. seq=7, arrival=09:32:13, departure=09:32:45, stop_id=1.134
#   08. seq=8, arrival=09:34:22, departure=09:35:05, stop_id=1.133
#   09. seq=9, arrival=09:36:18, departure=09:36:39, stop_id=1.132
#   10. seq=10, arrival=09:37:45, departure=09:38:17, stop_id=1.131
#   11. seq=11, arrival=09:39:39, departure=09:40:05, stop_id=1.130
#   12. seq=12, arrival=09:41:27, departure=09:41:53, stop_id=1.129
#   13. seq=13, arrival=09:42:48, departure=09:43:14, stop_id=1.128
#   14. seq=14, arrival=09:44:17, departure=09:44:43, stop_id=1.127
#   15. seq=15, arrival=09:45:43, departure=09:46:26, stop_id=1.126
#   16. seq=16, arrival=09:47:18, departure=09:47:44, stop_id=1.125
#   17. seq=17, arrival=09:49:02, departure=09:49:28, stop_id=1.124
#   18. seq=18, arrival=09:50:25, departure=09:50:51, stop_id=1.123
#   19. seq=19, arrival=09:51:56, departure=09:52:32, stop_id=1.122
#   20. seq=20, arrival=09:53:29, departure=09:53:50, stop_id=1.121
#   21. seq=21, arrival=09:54:42, departure=09:55:08, stop_id=1.120
#   22. seq=22, arrival=09:56:04, departure=09:56:25, stop_id=1.119
#   23. seq=23, arrival=09:57:38, departure=09:58:14, stop_id=1.118
#   24. seq=24, arrival=09:59:40, departure=10:00:05, stop_id=1.117
#   25. seq=25, arrival=10:01:05, departure=10:01:24, stop_id=1.116
#   26. seq=26, arrival=10:02:28, departure=10:02:47, stop_id=1.115
#   27. seq=27, arrival=10:03:48, departure=10:04:07, stop_id=1.114
#   28. seq=28, arrival=10:05:14, departure=10:05:36, stop_id=1.113
#   29. seq=29, arrival=10:07:16, departure=10:07:38, stop_id=1.112
#   30. seq=30, arrival=10:09:09, departure=10:09:09, stop_id=1.111
#
# Group 7: 2 trip_id  (kept: 1.1.11654316)
#   x 1.1.11655312
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=10:17:16, departure=10:17:16, stop_id=1.111
#   02. seq=2, arrival=10:18:42, departure=10:19:04, stop_id=1.112
#   03. seq=3, arrival=10:20:43, departure=10:21:05, stop_id=1.113
#   04. seq=4, arrival=10:22:14, departure=10:22:33, stop_id=1.114
#   05. seq=5, arrival=10:23:35, departure=10:23:54, stop_id=1.115
#   06. seq=6, arrival=10:24:57, departure=10:25:16, stop_id=1.116
#   07. seq=7, arrival=10:26:17, departure=10:26:39, stop_id=1.117
#   08. seq=8, arrival=10:28:10, departure=10:28:42, stop_id=1.118
#   09. seq=9, arrival=10:29:59, departure=10:30:18, stop_id=1.119
#   10. seq=10, arrival=10:31:20, departure=10:31:42, stop_id=1.120
#   11. seq=11, arrival=10:32:34, departure=10:32:53, stop_id=1.121
#   12. seq=12, arrival=10:33:52, departure=10:34:30, stop_id=1.122
#   13. seq=13, arrival=10:35:32, departure=10:35:54, stop_id=1.123
#   14. seq=14, arrival=10:36:51, departure=10:37:13, stop_id=1.124
#   15. seq=15, arrival=10:38:14, departure=10:38:36, stop_id=1.125
#   16. seq=16, arrival=10:39:31, departure=10:40:09, stop_id=1.126
#   17. seq=17, arrival=10:41:07, departure=10:41:29, stop_id=1.127
#   18. seq=18, arrival=10:42:37, departure=10:43:05, stop_id=1.128
#   19. seq=19, arrival=10:44:01, departure=10:44:23, stop_id=1.129
#   20. seq=20, arrival=10:45:44, departure=10:46:06, stop_id=1.130
#   21. seq=21, arrival=10:47:28, departure=10:47:56, stop_id=1.131
#   22. seq=22, arrival=10:49:04, departure=10:49:23, stop_id=1.132
#   23. seq=23, arrival=10:50:40, departure=10:51:18, stop_id=1.133
#   24. seq=24, arrival=10:52:48, departure=10:53:16, stop_id=1.134
#   25. seq=25, arrival=10:55:01, departure=10:55:23, stop_id=1.135
#   26. seq=26, arrival=10:56:33, departure=10:56:55, stop_id=1.136
#   27. seq=27, arrival=10:58:22, departure=10:58:41, stop_id=1.137
#   28. seq=28, arrival=10:59:49, departure=11:00:08, stop_id=1.138
#   29. seq=29, arrival=11:01:28, departure=11:01:50, stop_id=1.139
#   30. seq=30, arrival=11:03:13, departure=11:03:13, stop_id=1.140
#
# Group 8: 2 trip_id  (kept: 1.1.11654317)
#   x 1.1.11655313
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=11:08:43, departure=11:08:43, stop_id=1.140
#   02. seq=2, arrival=11:10:10, departure=11:10:32, stop_id=1.139
#   03. seq=3, arrival=11:11:56, departure=11:12:15, stop_id=1.138
#   04. seq=4, arrival=11:13:23, departure=11:13:42, stop_id=1.137
#   05. seq=5, arrival=11:15:02, departure=11:15:24, stop_id=1.136
#   06. seq=6, arrival=11:16:53, departure=11:17:15, stop_id=1.135
#   07. seq=7, arrival=11:18:56, departure=11:19:24, stop_id=1.134
#   08. seq=8, arrival=11:21:01, departure=11:21:39, stop_id=1.133
#   09. seq=9, arrival=11:22:52, departure=11:23:11, stop_id=1.132
#   10. seq=10, arrival=11:24:17, departure=11:24:45, stop_id=1.131
#   11. seq=11, arrival=11:26:07, departure=11:26:29, stop_id=1.130
#   12. seq=12, arrival=11:27:51, departure=11:28:13, stop_id=1.129
#   13. seq=13, arrival=11:29:08, departure=11:29:30, stop_id=1.128
#   14. seq=14, arrival=11:30:33, departure=11:30:55, stop_id=1.127
#   15. seq=15, arrival=11:31:55, departure=11:32:33, stop_id=1.126
#   16. seq=16, arrival=11:33:25, departure=11:33:47, stop_id=1.125
#   17. seq=17, arrival=11:35:05, departure=11:35:27, stop_id=1.124
#   18. seq=18, arrival=11:36:24, departure=11:36:46, stop_id=1.123
#   19. seq=19, arrival=11:37:51, departure=11:38:23, stop_id=1.122
#   20. seq=20, arrival=11:39:20, departure=11:39:39, stop_id=1.121
#   21. seq=21, arrival=11:40:31, departure=11:40:53, stop_id=1.120
#   22. seq=22, arrival=11:41:49, departure=11:42:08, stop_id=1.119
#   23. seq=23, arrival=11:43:21, departure=11:43:53, stop_id=1.118
#   24. seq=24, arrival=11:45:19, departure=11:45:41, stop_id=1.117
#   25. seq=25, arrival=11:46:41, departure=11:47:00, stop_id=1.116
#   26. seq=26, arrival=11:48:04, departure=11:48:23, stop_id=1.115
#   27. seq=27, arrival=11:49:24, departure=11:49:43, stop_id=1.114
#   28. seq=28, arrival=11:50:50, departure=11:51:12, stop_id=1.113
#   29. seq=29, arrival=11:52:52, departure=11:53:14, stop_id=1.112
#   30. seq=30, arrival=11:54:45, departure=11:54:45, stop_id=1.111
#
# Group 9: 2 trip_id  (kept: 1.1.11654318)
#   x 1.1.11655314
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=12:00:04, departure=12:00:04, stop_id=1.111
#   02. seq=2, arrival=12:01:30, departure=12:01:52, stop_id=1.112
#   03. seq=3, arrival=12:03:31, departure=12:03:53, stop_id=1.113
#   04. seq=4, arrival=12:05:02, departure=12:05:21, stop_id=1.114
#   05. seq=5, arrival=12:06:23, departure=12:06:42, stop_id=1.115
#   06. seq=6, arrival=12:07:45, departure=12:08:04, stop_id=1.116
#   07. seq=7, arrival=12:09:05, departure=12:09:27, stop_id=1.117
#   08. seq=8, arrival=12:10:58, departure=12:11:30, stop_id=1.118
#   09. seq=9, arrival=12:12:47, departure=12:13:06, stop_id=1.119
#   10. seq=10, arrival=12:14:08, departure=12:14:30, stop_id=1.120
#   11. seq=11, arrival=12:15:22, departure=12:15:41, stop_id=1.121
#   12. seq=12, arrival=12:16:40, departure=12:17:18, stop_id=1.122
#   13. seq=13, arrival=12:18:20, departure=12:18:42, stop_id=1.123
#   14. seq=14, arrival=12:19:39, departure=12:20:01, stop_id=1.124
#   15. seq=15, arrival=12:21:02, departure=12:21:24, stop_id=1.125
#   16. seq=16, arrival=12:22:19, departure=12:22:57, stop_id=1.126
#   17. seq=17, arrival=12:23:55, departure=12:24:17, stop_id=1.127
#   18. seq=18, arrival=12:25:25, departure=12:25:53, stop_id=1.128
#   19. seq=19, arrival=12:26:49, departure=12:27:11, stop_id=1.129
#   20. seq=20, arrival=12:28:32, departure=12:28:54, stop_id=1.130
#   21. seq=21, arrival=12:30:16, departure=12:30:44, stop_id=1.131
#   22. seq=22, arrival=12:31:52, departure=12:32:11, stop_id=1.132
#   23. seq=23, arrival=12:33:28, departure=12:34:06, stop_id=1.133
#   24. seq=24, arrival=12:35:36, departure=12:36:04, stop_id=1.134
#   25. seq=25, arrival=12:37:49, departure=12:38:11, stop_id=1.135
#   26. seq=26, arrival=12:39:21, departure=12:39:43, stop_id=1.136
#   27. seq=27, arrival=12:41:10, departure=12:41:29, stop_id=1.137
#   28. seq=28, arrival=12:42:37, departure=12:42:56, stop_id=1.138
#   29. seq=29, arrival=12:44:16, departure=12:44:38, stop_id=1.139
#   30. seq=30, arrival=12:46:01, departure=12:46:01, stop_id=1.140
#
# Group 10: 2 trip_id  (kept: 1.1.11654319)
#   x 1.1.11655315
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=12:51:31, departure=12:51:31, stop_id=1.140
#   02. seq=2, arrival=12:52:58, departure=12:53:20, stop_id=1.139
#   03. seq=3, arrival=12:54:44, departure=12:55:03, stop_id=1.138
#   04. seq=4, arrival=12:56:11, departure=12:56:30, stop_id=1.137
#   05. seq=5, arrival=12:57:50, departure=12:58:12, stop_id=1.136
#   06. seq=6, arrival=12:59:41, departure=13:00:03, stop_id=1.135
#   07. seq=7, arrival=13:01:44, departure=13:02:12, stop_id=1.134
#   08. seq=8, arrival=13:03:49, departure=13:04:27, stop_id=1.133
#   09. seq=9, arrival=13:05:40, departure=13:05:59, stop_id=1.132
#   10. seq=10, arrival=13:07:05, departure=13:07:33, stop_id=1.131
#   11. seq=11, arrival=13:08:55, departure=13:09:17, stop_id=1.130
#   12. seq=12, arrival=13:10:39, departure=13:11:01, stop_id=1.129
#   13. seq=13, arrival=13:11:56, departure=13:12:18, stop_id=1.128
#   14. seq=14, arrival=13:13:21, departure=13:13:43, stop_id=1.127
#   15. seq=15, arrival=13:14:43, departure=13:15:21, stop_id=1.126
#   16. seq=16, arrival=13:16:13, departure=13:16:35, stop_id=1.125
#   17. seq=17, arrival=13:17:53, departure=13:18:15, stop_id=1.124
#   18. seq=18, arrival=13:19:12, departure=13:19:34, stop_id=1.123
#   19. seq=19, arrival=13:20:39, departure=13:21:11, stop_id=1.122
#   20. seq=20, arrival=13:22:08, departure=13:22:27, stop_id=1.121
#   21. seq=21, arrival=13:23:19, departure=13:23:41, stop_id=1.120
#   22. seq=22, arrival=13:24:37, departure=13:24:56, stop_id=1.119
#   23. seq=23, arrival=13:26:09, departure=13:26:41, stop_id=1.118
#   24. seq=24, arrival=13:28:07, departure=13:28:29, stop_id=1.117
#   25. seq=25, arrival=13:29:29, departure=13:29:48, stop_id=1.116
#   26. seq=26, arrival=13:30:52, departure=13:31:11, stop_id=1.115
#   27. seq=27, arrival=13:32:12, departure=13:32:31, stop_id=1.114
#   28. seq=28, arrival=13:33:38, departure=13:34:00, stop_id=1.113
#   29. seq=29, arrival=13:35:40, departure=13:36:02, stop_id=1.112
#   30. seq=30, arrival=13:37:33, departure=13:37:33, stop_id=1.111
#
# Group 11: 2 trip_id  (kept: 1.1.11654320)
#   x 1.1.11655316
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=13:42:52, departure=13:42:52, stop_id=1.111
#   02. seq=2, arrival=13:44:18, departure=13:44:40, stop_id=1.112
#   03. seq=3, arrival=13:46:19, departure=13:46:41, stop_id=1.113
#   04. seq=4, arrival=13:47:50, departure=13:48:09, stop_id=1.114
#   05. seq=5, arrival=13:49:11, departure=13:49:30, stop_id=1.115
#   06. seq=6, arrival=13:50:33, departure=13:50:52, stop_id=1.116
#   07. seq=7, arrival=13:51:53, departure=13:52:15, stop_id=1.117
#   08. seq=8, arrival=13:53:46, departure=13:54:18, stop_id=1.118
#   09. seq=9, arrival=13:55:35, departure=13:55:54, stop_id=1.119
#   10. seq=10, arrival=13:56:56, departure=13:57:18, stop_id=1.120
#   11. seq=11, arrival=13:58:10, departure=13:58:29, stop_id=1.121
#   12. seq=12, arrival=13:59:28, departure=14:00:06, stop_id=1.122
#   13. seq=13, arrival=14:01:08, departure=14:01:30, stop_id=1.123
#   14. seq=14, arrival=14:02:27, departure=14:02:49, stop_id=1.124
#   15. seq=15, arrival=14:03:50, departure=14:04:12, stop_id=1.125
#   16. seq=16, arrival=14:05:07, departure=14:05:45, stop_id=1.126
#   17. seq=17, arrival=14:06:43, departure=14:07:05, stop_id=1.127
#   18. seq=18, arrival=14:08:13, departure=14:08:41, stop_id=1.128
#   19. seq=19, arrival=14:09:37, departure=14:09:59, stop_id=1.129
#   20. seq=20, arrival=14:11:20, departure=14:11:42, stop_id=1.130
#   21. seq=21, arrival=14:13:04, departure=14:13:32, stop_id=1.131
#   22. seq=22, arrival=14:14:40, departure=14:14:59, stop_id=1.132
#   23. seq=23, arrival=14:16:16, departure=14:16:54, stop_id=1.133
#   24. seq=24, arrival=14:18:24, departure=14:18:52, stop_id=1.134
#   25. seq=25, arrival=14:20:37, departure=14:20:59, stop_id=1.135
#   26. seq=26, arrival=14:22:09, departure=14:22:31, stop_id=1.136
#   27. seq=27, arrival=14:23:58, departure=14:24:17, stop_id=1.137
#   28. seq=28, arrival=14:25:25, departure=14:25:44, stop_id=1.138
#   29. seq=29, arrival=14:27:04, departure=14:27:26, stop_id=1.139
#   30. seq=30, arrival=14:28:49, departure=14:28:49, stop_id=1.140
#
# Group 12: 2 trip_id  (kept: 1.1.11654321)
#   x 1.1.11655317
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=14:34:19, departure=14:34:19, stop_id=1.140
#   02. seq=2, arrival=14:35:46, departure=14:36:08, stop_id=1.139
#   03. seq=3, arrival=14:37:32, departure=14:37:51, stop_id=1.138
#   04. seq=4, arrival=14:38:59, departure=14:39:18, stop_id=1.137
#   05. seq=5, arrival=14:40:38, departure=14:41:00, stop_id=1.136
#   06. seq=6, arrival=14:42:29, departure=14:42:51, stop_id=1.135
#   07. seq=7, arrival=14:44:32, departure=14:45:00, stop_id=1.134
#   08. seq=8, arrival=14:46:37, departure=14:47:15, stop_id=1.133
#   09. seq=9, arrival=14:48:28, departure=14:48:47, stop_id=1.132
#   10. seq=10, arrival=14:49:53, departure=14:50:21, stop_id=1.131
#   11. seq=11, arrival=14:51:43, departure=14:52:05, stop_id=1.130
#   12. seq=12, arrival=14:53:27, departure=14:53:49, stop_id=1.129
#   13. seq=13, arrival=14:54:44, departure=14:55:06, stop_id=1.128
#   14. seq=14, arrival=14:56:09, departure=14:56:31, stop_id=1.127
#   15. seq=15, arrival=14:57:31, departure=14:58:09, stop_id=1.126
#   16. seq=16, arrival=14:59:01, departure=14:59:23, stop_id=1.125
#   17. seq=17, arrival=15:00:41, departure=15:01:03, stop_id=1.124
#   18. seq=18, arrival=15:02:00, departure=15:02:22, stop_id=1.123
#   19. seq=19, arrival=15:03:27, departure=15:03:59, stop_id=1.122
#   20. seq=20, arrival=15:04:56, departure=15:05:15, stop_id=1.121
#   21. seq=21, arrival=15:06:07, departure=15:06:29, stop_id=1.120
#   22. seq=22, arrival=15:07:25, departure=15:07:44, stop_id=1.119
#   23. seq=23, arrival=15:08:57, departure=15:09:29, stop_id=1.118
#   24. seq=24, arrival=15:10:55, departure=15:11:17, stop_id=1.117
#   25. seq=25, arrival=15:12:17, departure=15:12:36, stop_id=1.116
#   26. seq=26, arrival=15:13:40, departure=15:13:59, stop_id=1.115
#   27. seq=27, arrival=15:15:00, departure=15:15:19, stop_id=1.114
#   28. seq=28, arrival=15:16:26, departure=15:16:48, stop_id=1.113
#   29. seq=29, arrival=15:18:28, departure=15:18:50, stop_id=1.112
#   30. seq=30, arrival=15:20:21, departure=15:20:21, stop_id=1.111
#
# Group 13: 2 trip_id  (kept: 1.1.11654322)
#   x 1.1.11655318
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=15:25:40, departure=15:25:40, stop_id=1.111
#   02. seq=2, arrival=15:27:06, departure=15:27:28, stop_id=1.112
#   03. seq=3, arrival=15:29:07, departure=15:29:29, stop_id=1.113
#   04. seq=4, arrival=15:30:38, departure=15:30:57, stop_id=1.114
#   05. seq=5, arrival=15:31:59, departure=15:32:18, stop_id=1.115
#   06. seq=6, arrival=15:33:21, departure=15:33:40, stop_id=1.116
#   07. seq=7, arrival=15:34:41, departure=15:35:03, stop_id=1.117
#   08. seq=8, arrival=15:36:34, departure=15:37:06, stop_id=1.118
#   09. seq=9, arrival=15:38:23, departure=15:38:42, stop_id=1.119
#   10. seq=10, arrival=15:39:44, departure=15:40:06, stop_id=1.120
#   11. seq=11, arrival=15:40:58, departure=15:41:17, stop_id=1.121
#   12. seq=12, arrival=15:42:16, departure=15:42:54, stop_id=1.122
#   13. seq=13, arrival=15:43:56, departure=15:44:18, stop_id=1.123
#   14. seq=14, arrival=15:45:15, departure=15:45:37, stop_id=1.124
#   15. seq=15, arrival=15:46:38, departure=15:47:00, stop_id=1.125
#   16. seq=16, arrival=15:47:55, departure=15:48:33, stop_id=1.126
#   17. seq=17, arrival=15:49:31, departure=15:49:53, stop_id=1.127
#   18. seq=18, arrival=15:51:01, departure=15:51:29, stop_id=1.128
#   19. seq=19, arrival=15:52:25, departure=15:52:47, stop_id=1.129
#   20. seq=20, arrival=15:54:08, departure=15:54:30, stop_id=1.130
#   21. seq=21, arrival=15:55:52, departure=15:56:20, stop_id=1.131
#   22. seq=22, arrival=15:57:28, departure=15:57:47, stop_id=1.132
#   23. seq=23, arrival=15:59:04, departure=15:59:42, stop_id=1.133
#   24. seq=24, arrival=16:01:12, departure=16:01:40, stop_id=1.134
#   25. seq=25, arrival=16:03:25, departure=16:03:47, stop_id=1.135
#   26. seq=26, arrival=16:04:57, departure=16:05:19, stop_id=1.136
#   27. seq=27, arrival=16:06:46, departure=16:07:05, stop_id=1.137
#   28. seq=28, arrival=16:08:13, departure=16:08:32, stop_id=1.138
#   29. seq=29, arrival=16:09:52, departure=16:10:14, stop_id=1.139
#   30. seq=30, arrival=16:11:37, departure=16:11:37, stop_id=1.140
#
# Group 14: 2 trip_id  (kept: 1.1.11654323)
#   x 1.1.11655319
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=16:17:07, departure=16:17:07, stop_id=1.140
#   02. seq=2, arrival=16:18:34, departure=16:18:56, stop_id=1.139
#   03. seq=3, arrival=16:20:20, departure=16:20:39, stop_id=1.138
#   04. seq=4, arrival=16:21:47, departure=16:22:06, stop_id=1.137
#   05. seq=5, arrival=16:23:26, departure=16:23:48, stop_id=1.136
#   06. seq=6, arrival=16:25:17, departure=16:25:39, stop_id=1.135
#   07. seq=7, arrival=16:27:20, departure=16:27:48, stop_id=1.134
#   08. seq=8, arrival=16:29:25, departure=16:30:03, stop_id=1.133
#   09. seq=9, arrival=16:31:16, departure=16:31:35, stop_id=1.132
#   10. seq=10, arrival=16:32:41, departure=16:33:09, stop_id=1.131
#   11. seq=11, arrival=16:34:31, departure=16:34:53, stop_id=1.130
#   12. seq=12, arrival=16:36:15, departure=16:36:37, stop_id=1.129
#   13. seq=13, arrival=16:37:32, departure=16:37:54, stop_id=1.128
#   14. seq=14, arrival=16:38:57, departure=16:39:19, stop_id=1.127
#   15. seq=15, arrival=16:40:19, departure=16:40:57, stop_id=1.126
#   16. seq=16, arrival=16:41:49, departure=16:42:11, stop_id=1.125
#   17. seq=17, arrival=16:43:29, departure=16:43:51, stop_id=1.124
#   18. seq=18, arrival=16:44:48, departure=16:45:10, stop_id=1.123
#   19. seq=19, arrival=16:46:15, departure=16:46:47, stop_id=1.122
#   20. seq=20, arrival=16:47:44, departure=16:48:03, stop_id=1.121
#   21. seq=21, arrival=16:48:55, departure=16:49:17, stop_id=1.120
#   22. seq=22, arrival=16:50:13, departure=16:50:32, stop_id=1.119
#   23. seq=23, arrival=16:51:45, departure=16:52:17, stop_id=1.118
#   24. seq=24, arrival=16:53:43, departure=16:54:05, stop_id=1.117
#   25. seq=25, arrival=16:55:05, departure=16:55:24, stop_id=1.116
#   26. seq=26, arrival=16:56:28, departure=16:56:47, stop_id=1.115
#   27. seq=27, arrival=16:57:48, departure=16:58:07, stop_id=1.114
#   28. seq=28, arrival=16:59:14, departure=16:59:36, stop_id=1.113
#   29. seq=29, arrival=17:01:16, departure=17:01:42, stop_id=1.112
#   30. seq=30, arrival=17:03:13, departure=17:03:13, stop_id=1.111
#
# Group 15: 2 trip_id  (kept: 1.1.11654324)
#   x 1.1.11655320
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=17:07:21, departure=17:07:21, stop_id=1.111
#   02. seq=2, arrival=17:08:47, departure=17:09:13, stop_id=1.112
#   03. seq=3, arrival=17:10:52, departure=17:11:18, stop_id=1.113
#   04. seq=4, arrival=17:12:27, departure=17:12:48, stop_id=1.114
#   05. seq=5, arrival=17:13:50, departure=17:14:11, stop_id=1.115
#   06. seq=6, arrival=17:15:14, departure=17:15:35, stop_id=1.116
#   07. seq=7, arrival=17:16:36, departure=17:17:02, stop_id=1.117
#   08. seq=8, arrival=17:18:33, departure=17:19:09, stop_id=1.118
#   09. seq=9, arrival=17:20:26, departure=17:20:47, stop_id=1.119
#   10. seq=10, arrival=17:21:49, departure=17:22:15, stop_id=1.120
#   11. seq=11, arrival=17:23:07, departure=17:23:28, stop_id=1.121
#   12. seq=12, arrival=17:24:27, departure=17:25:10, stop_id=1.122
#   13. seq=13, arrival=17:26:12, departure=17:26:38, stop_id=1.123
#   14. seq=14, arrival=17:27:35, departure=17:28:01, stop_id=1.124
#   15. seq=15, arrival=17:29:02, departure=17:29:28, stop_id=1.125
#   16. seq=16, arrival=17:30:23, departure=17:31:06, stop_id=1.126
#   17. seq=17, arrival=17:32:04, departure=17:32:30, stop_id=1.127
#   18. seq=18, arrival=17:33:38, departure=17:34:10, stop_id=1.128
#   19. seq=19, arrival=17:35:06, departure=17:35:32, stop_id=1.129
#   20. seq=20, arrival=17:36:53, departure=17:37:19, stop_id=1.130
#   21. seq=21, arrival=17:38:41, departure=17:39:13, stop_id=1.131
#   22. seq=22, arrival=17:40:21, departure=17:40:42, stop_id=1.132
#   23. seq=23, arrival=17:41:59, departure=17:42:42, stop_id=1.133
#   24. seq=24, arrival=17:44:12, departure=17:44:44, stop_id=1.134
#   25. seq=25, arrival=17:46:29, departure=17:46:55, stop_id=1.135
#   26. seq=26, arrival=17:48:05, departure=17:48:31, stop_id=1.136
#   27. seq=27, arrival=17:49:58, departure=17:50:19, stop_id=1.137
#   28. seq=28, arrival=17:51:27, departure=17:51:48, stop_id=1.138
#   29. seq=29, arrival=17:53:08, departure=17:53:34, stop_id=1.139
#   30. seq=30, arrival=17:54:57, departure=17:54:57, stop_id=1.140
#
# Group 16: 2 trip_id  (kept: 1.1.11654325)
#   x 1.1.11655321
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=17:59:52, departure=17:59:52, stop_id=1.140
#   02. seq=2, arrival=18:01:19, departure=18:01:45, stop_id=1.139
#   03. seq=3, arrival=18:03:09, departure=18:03:30, stop_id=1.138
#   04. seq=4, arrival=18:04:38, departure=18:04:59, stop_id=1.137
#   05. seq=5, arrival=18:06:19, departure=18:06:45, stop_id=1.136
#   06. seq=6, arrival=18:08:14, departure=18:08:40, stop_id=1.135
#   07. seq=7, arrival=18:10:21, departure=18:10:53, stop_id=1.134
#   08. seq=8, arrival=18:12:30, departure=18:13:13, stop_id=1.133
#   09. seq=9, arrival=18:14:26, departure=18:14:47, stop_id=1.132
#   10. seq=10, arrival=18:15:53, departure=18:16:25, stop_id=1.131
#   11. seq=11, arrival=18:17:47, departure=18:18:13, stop_id=1.130
#   12. seq=12, arrival=18:19:35, departure=18:20:01, stop_id=1.129
#   13. seq=13, arrival=18:20:56, departure=18:21:22, stop_id=1.128
#   14. seq=14, arrival=18:22:25, departure=18:22:51, stop_id=1.127
#   15. seq=15, arrival=18:23:51, departure=18:24:34, stop_id=1.126
#   16. seq=16, arrival=18:25:26, departure=18:25:52, stop_id=1.125
#   17. seq=17, arrival=18:27:10, departure=18:27:36, stop_id=1.124
#   18. seq=18, arrival=18:28:33, departure=18:28:59, stop_id=1.123
#   19. seq=19, arrival=18:30:04, departure=18:30:40, stop_id=1.122
#   20. seq=20, arrival=18:31:37, departure=18:31:58, stop_id=1.121
#   21. seq=21, arrival=18:32:50, departure=18:33:16, stop_id=1.120
#   22. seq=22, arrival=18:34:12, departure=18:34:33, stop_id=1.119
#   23. seq=23, arrival=18:35:46, departure=18:36:22, stop_id=1.118
#   24. seq=24, arrival=18:37:48, departure=18:38:14, stop_id=1.117
#   25. seq=25, arrival=18:39:14, departure=18:39:35, stop_id=1.116
#   26. seq=26, arrival=18:40:39, departure=18:41:00, stop_id=1.115
#   27. seq=27, arrival=18:42:01, departure=18:42:22, stop_id=1.114
#   28. seq=28, arrival=18:43:29, departure=18:43:55, stop_id=1.113
#   29. seq=29, arrival=18:45:35, departure=18:46:01, stop_id=1.112
#   30. seq=30, arrival=18:47:32, departure=18:47:32, stop_id=1.111
#
# Group 17: 2 trip_id  (kept: 1.1.11654326)
#   x 1.1.11655322
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=18:52:21, departure=18:52:21, stop_id=1.111
#   02. seq=2, arrival=18:53:47, departure=18:54:13, stop_id=1.112
#   03. seq=3, arrival=18:55:52, departure=18:56:18, stop_id=1.113
#   04. seq=4, arrival=18:57:27, departure=18:57:48, stop_id=1.114
#   05. seq=5, arrival=18:58:50, departure=18:59:11, stop_id=1.115
#   06. seq=6, arrival=19:00:14, departure=19:00:35, stop_id=1.116
#   07. seq=7, arrival=19:01:36, departure=19:02:02, stop_id=1.117
#   08. seq=8, arrival=19:03:33, departure=19:04:09, stop_id=1.118
#   09. seq=9, arrival=19:05:26, departure=19:05:47, stop_id=1.119
#   10. seq=10, arrival=19:06:49, departure=19:07:15, stop_id=1.120
#   11. seq=11, arrival=19:08:07, departure=19:08:28, stop_id=1.121
#   12. seq=12, arrival=19:09:27, departure=19:10:10, stop_id=1.122
#   13. seq=13, arrival=19:11:12, departure=19:11:38, stop_id=1.123
#   14. seq=14, arrival=19:12:35, departure=19:13:01, stop_id=1.124
#   15. seq=15, arrival=19:14:02, departure=19:14:28, stop_id=1.125
#   16. seq=16, arrival=19:15:23, departure=19:16:06, stop_id=1.126
#   17. seq=17, arrival=19:17:04, departure=19:17:30, stop_id=1.127
#   18. seq=18, arrival=19:18:38, departure=19:19:10, stop_id=1.128
#   19. seq=19, arrival=19:20:06, departure=19:20:32, stop_id=1.129
#   20. seq=20, arrival=19:21:53, departure=19:22:19, stop_id=1.130
#   21. seq=21, arrival=19:23:41, departure=19:24:13, stop_id=1.131
#   22. seq=22, arrival=19:25:21, departure=19:25:42, stop_id=1.132
#   23. seq=23, arrival=19:26:59, departure=19:27:42, stop_id=1.133
#   24. seq=24, arrival=19:29:12, departure=19:29:44, stop_id=1.134
#   25. seq=25, arrival=19:31:29, departure=19:31:55, stop_id=1.135
#   26. seq=26, arrival=19:33:05, departure=19:33:31, stop_id=1.136
#   27. seq=27, arrival=19:34:58, departure=19:35:19, stop_id=1.137
#   28. seq=28, arrival=19:36:27, departure=19:36:48, stop_id=1.138
#   29. seq=29, arrival=19:38:08, departure=19:38:34, stop_id=1.139
#   30. seq=30, arrival=19:39:57, departure=19:39:57, stop_id=1.140
#
# Group 18: 2 trip_id  (kept: 1.1.11654327)
#   x 1.1.11655323
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=19:44:52, departure=19:44:52, stop_id=1.140
#   02. seq=2, arrival=19:46:19, departure=19:46:45, stop_id=1.139
#   03. seq=3, arrival=19:48:09, departure=19:48:30, stop_id=1.138
#   04. seq=4, arrival=19:49:38, departure=19:49:59, stop_id=1.137
#   05. seq=5, arrival=19:51:19, departure=19:51:45, stop_id=1.136
#   06. seq=6, arrival=19:53:14, departure=19:53:40, stop_id=1.135
#   07. seq=7, arrival=19:55:21, departure=19:55:53, stop_id=1.134
#   08. seq=8, arrival=19:57:30, departure=19:58:13, stop_id=1.133
#   09. seq=9, arrival=19:59:26, departure=19:59:47, stop_id=1.132
#   10. seq=10, arrival=20:00:53, departure=20:01:25, stop_id=1.131
#   11. seq=11, arrival=20:02:47, departure=20:03:13, stop_id=1.130
#   12. seq=12, arrival=20:04:35, departure=20:05:01, stop_id=1.129
#   13. seq=13, arrival=20:05:56, departure=20:06:22, stop_id=1.128
#   14. seq=14, arrival=20:07:25, departure=20:07:51, stop_id=1.127
#   15. seq=15, arrival=20:08:51, departure=20:09:34, stop_id=1.126
#   16. seq=16, arrival=20:10:26, departure=20:10:52, stop_id=1.125
#   17. seq=17, arrival=20:12:10, departure=20:12:36, stop_id=1.124
#   18. seq=18, arrival=20:13:33, departure=20:13:59, stop_id=1.123
#   19. seq=19, arrival=20:15:04, departure=20:15:40, stop_id=1.122
#   20. seq=20, arrival=20:16:37, departure=20:16:58, stop_id=1.121
#   21. seq=21, arrival=20:17:50, departure=20:18:16, stop_id=1.120
#   22. seq=22, arrival=20:19:12, departure=20:19:33, stop_id=1.119
#   23. seq=23, arrival=20:20:46, departure=20:21:22, stop_id=1.118
#   24. seq=24, arrival=20:22:48, departure=20:23:14, stop_id=1.117
#   25. seq=25, arrival=20:24:14, departure=20:24:35, stop_id=1.116
#   26. seq=26, arrival=20:25:39, departure=20:26:00, stop_id=1.115
#   27. seq=27, arrival=20:27:01, departure=20:27:22, stop_id=1.114
#   28. seq=28, arrival=20:28:29, departure=20:28:55, stop_id=1.113
#   29. seq=29, arrival=20:30:35, departure=20:31:01, stop_id=1.112
#   30. seq=30, arrival=20:32:32, departure=20:32:32, stop_id=1.111
#
# Group 19: 2 trip_id  (kept: 1.1.11654329)
#   x 1.1.11655325
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=21:33:10, departure=21:33:10, stop_id=1.140
#   02. seq=2, arrival=21:34:37, departure=21:35:03, stop_id=1.139
#   03. seq=3, arrival=21:36:27, departure=21:36:48, stop_id=1.138
#   04. seq=4, arrival=21:37:56, departure=21:38:17, stop_id=1.137
#   05. seq=5, arrival=21:39:37, departure=21:40:03, stop_id=1.136
#   06. seq=6, arrival=21:41:32, departure=21:41:58, stop_id=1.135
#   07. seq=7, arrival=21:43:39, departure=21:44:11, stop_id=1.134
#   08. seq=8, arrival=21:45:48, departure=21:46:31, stop_id=1.133
#   09. seq=9, arrival=21:47:44, departure=21:48:05, stop_id=1.132
#   10. seq=10, arrival=21:49:11, departure=21:49:43, stop_id=1.131
#   11. seq=11, arrival=21:51:05, departure=21:51:31, stop_id=1.130
#   12. seq=12, arrival=21:52:53, departure=21:53:19, stop_id=1.129
#   13. seq=13, arrival=21:54:14, departure=21:54:40, stop_id=1.128
#   14. seq=14, arrival=21:55:43, departure=21:56:09, stop_id=1.127
#   15. seq=15, arrival=21:57:09, departure=21:57:52, stop_id=1.126
#   16. seq=16, arrival=21:58:44, departure=21:59:10, stop_id=1.125
#   17. seq=17, arrival=22:00:28, departure=22:00:46, stop_id=1.124
#   18. seq=18, arrival=22:01:43, departure=22:02:01, stop_id=1.123
#   19. seq=19, arrival=22:03:06, departure=22:03:30, stop_id=1.122
#   20. seq=20, arrival=22:04:27, departure=22:04:42, stop_id=1.121
#   21. seq=21, arrival=22:05:34, departure=22:05:52, stop_id=1.120
#   22. seq=22, arrival=22:06:48, departure=22:07:03, stop_id=1.119
#   23. seq=23, arrival=22:08:16, departure=22:08:40, stop_id=1.118
#   24. seq=24, arrival=22:10:06, departure=22:10:24, stop_id=1.117
#   25. seq=25, arrival=22:11:24, departure=22:11:39, stop_id=1.116
#   26. seq=26, arrival=22:12:43, departure=22:12:58, stop_id=1.115
#   27. seq=27, arrival=22:13:59, departure=22:14:14, stop_id=1.114
#   28. seq=28, arrival=22:15:21, departure=22:15:39, stop_id=1.113
#   29. seq=29, arrival=22:17:19, departure=22:17:37, stop_id=1.112
#   30. seq=30, arrival=22:19:08, departure=22:19:08, stop_id=1.111
#
# Group 20: 2 trip_id  (kept: 1.1.11654331)
#   x 1.1.11655327
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=23:10:14, departure=23:10:14, stop_id=1.140
#   02. seq=2, arrival=23:11:41, departure=23:11:59, stop_id=1.139
#   03. seq=3, arrival=23:13:23, departure=23:13:38, stop_id=1.138
#   04. seq=4, arrival=23:14:46, departure=23:15:01, stop_id=1.137
#   05. seq=5, arrival=23:16:21, departure=23:16:39, stop_id=1.136
#   06. seq=6, arrival=23:18:08, departure=23:18:26, stop_id=1.135
#   07. seq=7, arrival=23:20:07, departure=23:20:31, stop_id=1.134
#   08. seq=8, arrival=23:22:08, departure=23:22:38, stop_id=1.133
#   09. seq=9, arrival=23:23:51, departure=23:24:06, stop_id=1.132
#   10. seq=10, arrival=23:25:12, departure=23:25:36, stop_id=1.131
#   11. seq=11, arrival=23:26:58, departure=23:27:16, stop_id=1.130
#   12. seq=12, arrival=23:28:38, departure=23:28:56, stop_id=1.129
#   13. seq=13, arrival=23:29:51, departure=23:30:09, stop_id=1.128
#   14. seq=14, arrival=23:31:12, departure=23:31:30, stop_id=1.127
#   15. seq=15, arrival=23:32:30, departure=23:33:00, stop_id=1.126
#   16. seq=16, arrival=23:33:52, departure=23:34:10, stop_id=1.125
#   17. seq=17, arrival=23:35:28, departure=23:35:46, stop_id=1.124
#   18. seq=18, arrival=23:36:43, departure=23:37:01, stop_id=1.123
#   19. seq=19, arrival=23:38:06, departure=23:38:30, stop_id=1.122
#   20. seq=20, arrival=23:39:27, departure=23:39:42, stop_id=1.121
#   21. seq=21, arrival=23:40:34, departure=23:40:52, stop_id=1.120
#   22. seq=22, arrival=23:41:48, departure=23:42:03, stop_id=1.119
#   23. seq=23, arrival=23:43:16, departure=23:43:40, stop_id=1.118
#   24. seq=24, arrival=23:45:06, departure=23:45:24, stop_id=1.117
#   25. seq=25, arrival=23:46:24, departure=23:46:39, stop_id=1.116
#   26. seq=26, arrival=23:47:43, departure=23:47:58, stop_id=1.115
#   27. seq=27, arrival=23:48:59, departure=23:49:14, stop_id=1.114
#   28. seq=28, arrival=23:50:21, departure=23:50:39, stop_id=1.113
#   29. seq=29, arrival=23:52:19, departure=23:52:37, stop_id=1.112
#   30. seq=30, arrival=23:54:08, departure=23:54:08, stop_id=1.111
#
# Group 21: 2 trip_id  (kept: 1.1.11654333)
#   x 1.1.11655331
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=06:04:59, departure=06:04:59, stop_id=1.136
#   02. seq=2, arrival=06:06:28, departure=06:06:54, stop_id=1.135
#   03. seq=3, arrival=06:08:35, departure=06:09:07, stop_id=1.134
#   04. seq=4, arrival=06:10:44, departure=06:11:27, stop_id=1.133
#   05. seq=5, arrival=06:12:40, departure=06:13:01, stop_id=1.132
#   06. seq=6, arrival=06:14:07, departure=06:14:39, stop_id=1.131
#   07. seq=7, arrival=06:16:01, departure=06:16:27, stop_id=1.130
#   08. seq=8, arrival=06:17:49, departure=06:18:15, stop_id=1.129
#   09. seq=9, arrival=06:19:10, departure=06:19:36, stop_id=1.128
#   10. seq=10, arrival=06:20:39, departure=06:21:05, stop_id=1.127
#   11. seq=11, arrival=06:22:05, departure=06:22:48, stop_id=1.126
#   12. seq=12, arrival=06:23:40, departure=06:24:06, stop_id=1.125
#   13. seq=13, arrival=06:25:24, departure=06:25:50, stop_id=1.124
#   14. seq=14, arrival=06:26:47, departure=06:27:13, stop_id=1.123
#   15. seq=15, arrival=06:28:18, departure=06:28:54, stop_id=1.122
#   16. seq=16, arrival=06:29:51, departure=06:30:12, stop_id=1.121
#   17. seq=17, arrival=06:31:04, departure=06:31:30, stop_id=1.120
#   18. seq=18, arrival=06:32:26, departure=06:32:47, stop_id=1.119
#   19. seq=19, arrival=06:34:00, departure=06:34:36, stop_id=1.118
#   20. seq=20, arrival=06:36:02, departure=06:36:28, stop_id=1.117
#   21. seq=21, arrival=06:37:28, departure=06:37:49, stop_id=1.116
#   22. seq=22, arrival=06:38:53, departure=06:39:14, stop_id=1.115
#   23. seq=23, arrival=06:40:15, departure=06:40:36, stop_id=1.114
#   24. seq=24, arrival=06:41:43, departure=06:42:09, stop_id=1.113
#   25. seq=25, arrival=06:43:49, departure=06:44:15, stop_id=1.112
#   26. seq=26, arrival=06:45:46, departure=06:45:46, stop_id=1.111
#
# Group 22: 2 trip_id  (kept: 1.1.11654334)
#   x 1.1.11655332
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=06:50:40, departure=06:50:40, stop_id=1.111
#   02. seq=2, arrival=06:52:06, departure=06:52:32, stop_id=1.112
#   03. seq=3, arrival=06:54:11, departure=06:54:37, stop_id=1.113
#   04. seq=4, arrival=06:55:46, departure=06:56:07, stop_id=1.114
#   05. seq=5, arrival=06:57:09, departure=06:57:30, stop_id=1.115
#   06. seq=6, arrival=06:58:33, departure=06:58:54, stop_id=1.116
#   07. seq=7, arrival=06:59:55, departure=07:00:21, stop_id=1.117
#   08. seq=8, arrival=07:01:52, departure=07:02:28, stop_id=1.118
#   09. seq=9, arrival=07:03:45, departure=07:04:06, stop_id=1.119
#   10. seq=10, arrival=07:05:08, departure=07:05:34, stop_id=1.120
#   11. seq=11, arrival=07:06:26, departure=07:06:47, stop_id=1.121
#   12. seq=12, arrival=07:07:46, departure=07:08:29, stop_id=1.122
#   13. seq=13, arrival=07:09:31, departure=07:09:57, stop_id=1.123
#   14. seq=14, arrival=07:10:54, departure=07:11:20, stop_id=1.124
#   15. seq=15, arrival=07:12:21, departure=07:12:47, stop_id=1.125
#   16. seq=16, arrival=07:13:42, departure=07:14:25, stop_id=1.126
#   17. seq=17, arrival=07:15:23, departure=07:15:49, stop_id=1.127
#   18. seq=18, arrival=07:16:57, departure=07:17:29, stop_id=1.128
#   19. seq=19, arrival=07:18:25, departure=07:18:51, stop_id=1.129
#   20. seq=20, arrival=07:20:12, departure=07:20:38, stop_id=1.130
#   21. seq=21, arrival=07:22:00, departure=07:22:32, stop_id=1.131
#   22. seq=22, arrival=07:23:40, departure=07:24:01, stop_id=1.132
#   23. seq=23, arrival=07:25:18, departure=07:26:01, stop_id=1.133
#   24. seq=24, arrival=07:27:31, departure=07:28:03, stop_id=1.134
#   25. seq=25, arrival=07:29:48, departure=07:30:14, stop_id=1.135
#   26. seq=26, arrival=07:31:24, departure=07:31:50, stop_id=1.136
#   27. seq=27, arrival=07:33:17, departure=07:33:38, stop_id=1.137
#   28. seq=28, arrival=07:34:46, departure=07:35:07, stop_id=1.138
#   29. seq=29, arrival=07:36:27, departure=07:36:53, stop_id=1.139
#   30. seq=30, arrival=07:38:16, departure=07:38:16, stop_id=1.140
#
# Group 23: 2 trip_id  (kept: 1.1.11654335)
#   x 1.1.11655333
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=07:43:04, departure=07:43:04, stop_id=1.140
#   02. seq=2, arrival=07:44:31, departure=07:44:57, stop_id=1.139
#   03. seq=3, arrival=07:46:21, departure=07:46:42, stop_id=1.138
#   04. seq=4, arrival=07:47:50, departure=07:48:11, stop_id=1.137
#   05. seq=5, arrival=07:49:31, departure=07:49:57, stop_id=1.136
#   06. seq=6, arrival=07:51:26, departure=07:51:52, stop_id=1.135
#   07. seq=7, arrival=07:53:33, departure=07:54:05, stop_id=1.134
#   08. seq=8, arrival=07:55:42, departure=07:56:25, stop_id=1.133
#   09. seq=9, arrival=07:57:38, departure=07:57:59, stop_id=1.132
#   10. seq=10, arrival=07:59:05, departure=07:59:37, stop_id=1.131
#   11. seq=11, arrival=08:00:59, departure=08:01:25, stop_id=1.130
#   12. seq=12, arrival=08:02:47, departure=08:03:13, stop_id=1.129
#   13. seq=13, arrival=08:04:08, departure=08:04:34, stop_id=1.128
#   14. seq=14, arrival=08:05:37, departure=08:06:03, stop_id=1.127
#   15. seq=15, arrival=08:07:03, departure=08:07:46, stop_id=1.126
#   16. seq=16, arrival=08:08:38, departure=08:09:04, stop_id=1.125
#   17. seq=17, arrival=08:10:22, departure=08:10:48, stop_id=1.124
#   18. seq=18, arrival=08:11:45, departure=08:12:11, stop_id=1.123
#   19. seq=19, arrival=08:13:16, departure=08:13:52, stop_id=1.122
#   20. seq=20, arrival=08:14:49, departure=08:15:10, stop_id=1.121
#   21. seq=21, arrival=08:16:02, departure=08:16:28, stop_id=1.120
#   22. seq=22, arrival=08:17:24, departure=08:17:45, stop_id=1.119
#   23. seq=23, arrival=08:18:58, departure=08:19:34, stop_id=1.118
#   24. seq=24, arrival=08:21:00, departure=08:21:26, stop_id=1.117
#   25. seq=25, arrival=08:22:26, departure=08:22:47, stop_id=1.116
#   26. seq=26, arrival=08:23:51, departure=08:24:12, stop_id=1.115
# ...
#   09. seq=9, arrival=05:14:21, departure=05:14:46, stop_id=1.914
#   10. seq=10, arrival=05:16:13, departure=05:16:38, stop_id=1.915
#   11. seq=11, arrival=05:17:53, departure=05:17:53, stop_id=1.916
#
# Group 4067: 3 trip_id  (kept: 1.101.11427343)
#   x 1.101.11427852
#   x 1.101.11428501
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.916
#   02. seq=2, arrival=05:02:15, departure=05:02:40, stop_id=1.915
#   03. seq=3, arrival=05:04:08, departure=05:04:33, stop_id=1.914
#   04. seq=4, arrival=05:05:30, departure=05:06:11, stop_id=1.959
#   05. seq=5, arrival=05:07:21, departure=05:08:02, stop_id=1.958
#   06. seq=6, arrival=05:09:05, departure=05:09:46, stop_id=1.957
#   07. seq=7, arrival=05:10:50, departure=05:11:30, stop_id=1.956
#   08. seq=8, arrival=05:13:53, departure=05:14:33, stop_id=1.954
#   09. seq=9, arrival=05:16:05, departure=05:16:45, stop_id=1.953
#   10. seq=10, arrival=05:18:06, departure=05:18:31, stop_id=1.952
#   11. seq=11, arrival=05:20:13, departure=05:20:13, stop_id=1.951
#
# Group 4068: 3 trip_id  (kept: 1.104.11430143)
#   x 1.104.11571772
#   x 1.104.11572398
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.932
#   02. seq=2, arrival=05:02:07, departure=05:02:07, stop_id=1.930
#
# Group 4069: 3 trip_id  (kept: 1.104.11430144)
#   x 1.104.11571773
#   x 1.104.11572399
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:04:27, departure=05:04:27, stop_id=1.930
#   02. seq=2, arrival=05:07:05, departure=05:07:41, stop_id=1.932
#   03. seq=3, arrival=05:09:45, departure=05:10:10, stop_id=1.933
#   04. seq=4, arrival=05:11:51, departure=05:12:16, stop_id=1.934
#   05. seq=5, arrival=05:13:25, departure=05:13:50, stop_id=1.935
#   06. seq=6, arrival=05:15:34, departure=05:15:34, stop_id=1.936
#
# Group 4070: 3 trip_id  (kept: 1.104.11430195)
#   x 1.104.11571913
#   x 1.104.11572548
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=15:58:54, departure=15:58:54, stop_id=1.936
#   02. seq=2, arrival=16:00:39, departure=16:01:04, stop_id=1.935
#   03. seq=3, arrival=16:02:14, departure=16:02:39, stop_id=1.934
#   04. seq=4, arrival=16:04:29, departure=16:04:54, stop_id=1.933
#   05. seq=5, arrival=16:06:57, departure=16:07:22, stop_id=1.932
#   06. seq=6, arrival=16:09:29, departure=16:09:29, stop_id=1.930
#
# Group 4071: 3 trip_id  (kept: 1.104.11430196)
#   x 1.104.11571914
#   x 1.104.11572549
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=16:11:49, departure=16:11:49, stop_id=1.930
#   02. seq=2, arrival=16:14:27, departure=16:14:52, stop_id=1.932
#   03. seq=3, arrival=16:16:56, departure=16:17:21, stop_id=1.933
#   04. seq=4, arrival=16:19:02, departure=16:19:27, stop_id=1.934
#   05. seq=5, arrival=16:20:36, departure=16:21:01, stop_id=1.935
#   06. seq=6, arrival=16:22:45, departure=16:22:45, stop_id=1.936
#
# Group 4072: 3 trip_id  (kept: 1.104.11430533)
#   x 1.104.11572096
#   x 1.104.11572755
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:22:01, departure=05:22:01, stop_id=1.930
#   02. seq=2, arrival=05:24:39, departure=05:25:04, stop_id=1.932
#   03. seq=3, arrival=05:27:08, departure=05:27:33, stop_id=1.933
#   04. seq=4, arrival=05:29:14, departure=05:29:39, stop_id=1.934
#   05. seq=5, arrival=05:30:48, departure=05:31:13, stop_id=1.935
#   06. seq=6, arrival=05:32:57, departure=05:32:57, stop_id=1.936
#
# Group 4073: 3 trip_id  (kept: 1.5.11674934)
#   x 1.5.11703557
#   x 1.5.11704249
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=13:51:51, departure=13:51:51, stop_id=1.534
#   02. seq=2, arrival=13:53:13, departure=13:53:36, stop_id=1.533
#   03. seq=3, arrival=13:55:01, departure=13:55:18, stop_id=1.532
#   04. seq=4, arrival=13:56:38, departure=13:57:04, stop_id=1.531
#   05. seq=5, arrival=13:58:20, departure=13:58:43, stop_id=1.530
#   06. seq=6, arrival=14:00:00, departure=14:00:34, stop_id=1.529
#   07. seq=7, arrival=14:01:37, departure=14:02:03, stop_id=1.528
#   08. seq=8, arrival=14:02:59, departure=14:03:25, stop_id=1.527
#   09. seq=9, arrival=14:05:00, departure=14:05:34, stop_id=1.526
#   10. seq=10, arrival=14:07:11, departure=14:07:34, stop_id=1.525
#   11. seq=11, arrival=14:08:40, departure=14:09:00, stop_id=1.524
#   12. seq=12, arrival=14:10:30, departure=14:11:04, stop_id=1.523
#   13. seq=13, arrival=14:12:20, departure=14:12:40, stop_id=1.522
#   14. seq=14, arrival=14:14:01, departure=14:14:27, stop_id=1.521
#   15. seq=15, arrival=14:15:49, departure=14:16:12, stop_id=1.520
#   16. seq=16, arrival=14:17:20, departure=14:17:43, stop_id=1.519
#   17. seq=17, arrival=14:18:57, departure=14:19:17, stop_id=1.518
#   18. seq=18, arrival=14:20:31, departure=14:20:48, stop_id=1.517
#   19. seq=19, arrival=14:21:55, departure=14:22:15, stop_id=1.516
#   20. seq=20, arrival=14:23:23, departure=14:23:43, stop_id=1.515
#   21. seq=21, arrival=14:24:28, departure=14:24:48, stop_id=1.555
#   22. seq=22, arrival=14:26:12, departure=14:26:38, stop_id=1.514
#   23. seq=23, arrival=14:27:58, departure=14:28:18, stop_id=1.513
#   24. seq=24, arrival=14:29:42, departure=14:30:02, stop_id=1.512
#   25. seq=25, arrival=14:31:16, departure=14:31:33, stop_id=1.511
#   26. seq=26, arrival=14:32:53, departure=14:33:13, stop_id=1.510
#   27. seq=27, arrival=14:34:35, departure=14:34:35, stop_id=1.509
#
# Group 4074: 3 trip_id  (kept: 1.5.11675053)
#   x 1.5.11703702
#   x 1.5.11704399
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.534
#   02. seq=2, arrival=05:01:22, departure=05:01:42, stop_id=1.533
#   03. seq=3, arrival=05:03:07, departure=05:03:27, stop_id=1.532
#   04. seq=4, arrival=05:04:47, departure=05:05:07, stop_id=1.531
#   05. seq=5, arrival=05:06:23, departure=05:06:43, stop_id=1.530
#   06. seq=6, arrival=05:08:00, departure=05:08:20, stop_id=1.529
#   07. seq=7, arrival=05:09:23, departure=05:09:43, stop_id=1.528
#   08. seq=8, arrival=05:10:39, departure=05:10:59, stop_id=1.527
#   09. seq=9, arrival=05:12:34, departure=05:12:54, stop_id=1.526
#   10. seq=10, arrival=05:14:31, departure=05:14:51, stop_id=1.525
#   11. seq=11, arrival=05:15:57, departure=05:16:17, stop_id=1.524
#   12. seq=12, arrival=05:17:47, departure=05:18:07, stop_id=1.523
#   13. seq=13, arrival=05:19:23, departure=05:19:43, stop_id=1.522
#   14. seq=14, arrival=05:21:04, departure=05:21:24, stop_id=1.521
#   15. seq=15, arrival=05:22:46, departure=05:23:06, stop_id=1.520
#   16. seq=16, arrival=05:24:14, departure=05:24:34, stop_id=1.519
#   17. seq=17, arrival=05:25:48, departure=05:26:08, stop_id=1.518
#   18. seq=18, arrival=05:27:22, departure=05:27:42, stop_id=1.517
#   19. seq=19, arrival=05:28:49, departure=05:29:09, stop_id=1.516
#   20. seq=20, arrival=05:30:17, departure=05:30:37, stop_id=1.515
#   21. seq=21, arrival=05:31:22, departure=05:31:42, stop_id=1.555
#   22. seq=22, arrival=05:33:06, departure=05:33:26, stop_id=1.514
#   23. seq=23, arrival=05:34:46, departure=05:35:06, stop_id=1.513
#   24. seq=24, arrival=05:36:30, departure=05:36:50, stop_id=1.512
#   25. seq=25, arrival=05:38:04, departure=05:38:24, stop_id=1.511
#   26. seq=26, arrival=05:39:44, departure=05:40:04, stop_id=1.510
#   27. seq=27, arrival=05:41:26, departure=05:41:26, stop_id=1.509
#
# Group 4075: 3 trip_id  (kept: 1.5.11675202)
#   x 1.5.11703903
#   x 1.5.11704612
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=17:51:39, departure=17:51:39, stop_id=1.534
#   02. seq=2, arrival=17:53:01, departure=17:53:24, stop_id=1.533
#   03. seq=3, arrival=17:54:49, departure=17:55:06, stop_id=1.532
#   04. seq=4, arrival=17:56:26, departure=17:56:52, stop_id=1.531
#   05. seq=5, arrival=17:58:08, departure=17:58:31, stop_id=1.530
#   06. seq=6, arrival=17:59:48, departure=18:00:22, stop_id=1.529
#   07. seq=7, arrival=18:01:25, departure=18:01:51, stop_id=1.528
#   08. seq=8, arrival=18:02:47, departure=18:03:13, stop_id=1.527
#   09. seq=9, arrival=18:04:48, departure=18:05:22, stop_id=1.526
#   10. seq=10, arrival=18:06:59, departure=18:07:22, stop_id=1.525
#   11. seq=11, arrival=18:08:28, departure=18:08:48, stop_id=1.524
#   12. seq=12, arrival=18:10:18, departure=18:10:52, stop_id=1.523
#   13. seq=13, arrival=18:12:08, departure=18:12:28, stop_id=1.522
#   14. seq=14, arrival=18:13:49, departure=18:14:15, stop_id=1.521
#   15. seq=15, arrival=18:15:37, departure=18:16:00, stop_id=1.520
#   16. seq=16, arrival=18:17:08, departure=18:17:31, stop_id=1.519
#   17. seq=17, arrival=18:18:45, departure=18:19:05, stop_id=1.518
#   18. seq=18, arrival=18:20:19, departure=18:20:36, stop_id=1.517
#   19. seq=19, arrival=18:21:43, departure=18:22:04, stop_id=1.516
#   20. seq=20, arrival=18:23:12, departure=18:23:33, stop_id=1.515
#   21. seq=21, arrival=18:24:18, departure=18:24:38, stop_id=1.555
#   22. seq=22, arrival=18:26:02, departure=18:26:26, stop_id=1.514
#   23. seq=23, arrival=18:27:46, departure=18:28:03, stop_id=1.513
#   24. seq=24, arrival=18:29:27, departure=18:29:44, stop_id=1.512
#   25. seq=25, arrival=18:30:58, departure=18:31:15, stop_id=1.511
#   26. seq=26, arrival=18:32:35, departure=18:32:56, stop_id=1.510
#   27. seq=27, arrival=18:34:18, departure=18:34:18, stop_id=1.509
#
# Group 4076: 3 trip_id  (kept: 1.5.11675275)
#   x 1.5.11703435
#   x 1.5.11704124
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.509
#   02. seq=2, arrival=05:01:21, departure=05:01:41, stop_id=1.510
#   03. seq=3, arrival=05:03:06, departure=05:03:26, stop_id=1.511
#   04. seq=4, arrival=05:04:38, departure=05:04:58, stop_id=1.512
#   05. seq=5, arrival=05:06:18, departure=05:06:38, stop_id=1.513
#   06. seq=6, arrival=05:07:59, departure=05:08:19, stop_id=1.514
#   07. seq=7, arrival=05:09:36, departure=05:09:56, stop_id=1.555
#   08. seq=8, arrival=05:10:41, departure=05:11:01, stop_id=1.515
#   09. seq=9, arrival=05:12:11, departure=05:12:31, stop_id=1.516
#   10. seq=10, arrival=05:13:40, departure=05:14:00, stop_id=1.517
#   11. seq=11, arrival=05:15:17, departure=05:15:37, stop_id=1.518
#   12. seq=12, arrival=05:16:52, departure=05:17:12, stop_id=1.519
#   13. seq=13, arrival=05:18:19, departure=05:18:39, stop_id=1.520
#   14. seq=14, arrival=05:19:57, departure=05:20:17, stop_id=1.521
#   15. seq=15, arrival=05:21:37, departure=05:21:57, stop_id=1.522
#   16. seq=16, arrival=05:23:14, departure=05:23:34, stop_id=1.523
#   17. seq=17, arrival=05:24:59, departure=05:25:19, stop_id=1.524
#   18. seq=18, arrival=05:26:26, departure=05:26:46, stop_id=1.525
#   19. seq=19, arrival=05:28:25, departure=05:28:45, stop_id=1.526
#   20. seq=20, arrival=05:29:56, departure=05:30:16, stop_id=1.527
#   21. seq=21, arrival=05:31:14, departure=05:31:34, stop_id=1.528
#   22. seq=22, arrival=05:32:36, departure=05:32:56, stop_id=1.529
#   23. seq=23, arrival=05:34:06, departure=05:34:26, stop_id=1.530
#   24. seq=24, arrival=05:35:45, departure=05:36:05, stop_id=1.531
#   25. seq=25, arrival=05:37:28, departure=05:37:48, stop_id=1.532
#   26. seq=26, arrival=05:39:10, departure=05:39:30, stop_id=1.533
#   27. seq=27, arrival=05:40:58, departure=05:40:58, stop_id=1.534
#
# Group 4077: 3 trip_id  (kept: 1.91.11427217)
#   x 1.91.11427724
#   x 1.91.11428357
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.909
#   02. seq=2, arrival=05:02:36, departure=05:03:01, stop_id=1.907
#   03. seq=3, arrival=05:04:34, departure=05:04:59, stop_id=1.906
#   04. seq=4, arrival=05:06:25, departure=05:06:50, stop_id=1.905
#   05. seq=5, arrival=05:08:55, departure=05:09:20, stop_id=1.904
#   06. seq=6, arrival=05:10:44, departure=05:11:14, stop_id=1.903
#   07. seq=7, arrival=05:15:19, departure=05:15:19, stop_id=1.901
#
# Group 4078: 3 trip_id  (kept: 1.91.11427252)
#   x 1.91.11427760
#   x 1.91.11428396
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.909
#   02. seq=2, arrival=05:01:47, departure=05:02:10, stop_id=1.910
#   03. seq=3, arrival=05:04:12, departure=05:05:26, stop_id=1.911
#   04. seq=4, arrival=05:07:18, departure=05:08:34, stop_id=1.912
#   05. seq=5, arrival=05:09:45, departure=05:10:10, stop_id=1.913
#   06. seq=6, arrival=05:11:24, departure=05:11:49, stop_id=1.914
#   07. seq=7, arrival=05:13:16, departure=05:13:41, stop_id=1.915
#   08. seq=8, arrival=05:14:56, departure=05:15:31, stop_id=1.916
#   09. seq=9, arrival=05:17:06, departure=05:17:06, stop_id=1.918
#
# Group 4079: 3 trip_id  (kept: 1.94.11430327)
#   x 1.94.11571950
#   x 1.94.11572595
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:17:45, departure=05:17:45, stop_id=1.930
#   02. seq=2, arrival=05:20:23, departure=05:20:48, stop_id=1.932
#   03. seq=3, arrival=05:22:52, departure=05:23:17, stop_id=1.933
#   04. seq=4, arrival=05:24:56, departure=05:25:21, stop_id=1.940
#   05. seq=5, arrival=05:26:30, departure=05:26:55, stop_id=1.941
#   06. seq=6, arrival=05:28:21, departure=05:28:46, stop_id=1.942
#   07. seq=7, arrival=05:29:56, departure=05:30:21, stop_id=1.943
#   08. seq=8, arrival=05:31:35, departure=05:32:00, stop_id=1.944
#   09. seq=9, arrival=05:33:46, departure=05:33:46, stop_id=1.945
#
# Group 4080: 4 trip_id  (kept: 1.104.11428897)
#   x 1.104.11430235
#   x 1.104.11571861
#   x 1.104.11572496
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.936
#   02. seq=2, arrival=05:01:45, departure=05:02:10, stop_id=1.935
#   03. seq=3, arrival=05:03:20, departure=05:03:45, stop_id=1.934
#   04. seq=4, arrival=05:05:35, departure=05:06:00, stop_id=1.933
#   05. seq=5, arrival=05:08:03, departure=05:08:28, stop_id=1.932
#   06. seq=6, arrival=05:10:35, departure=05:10:35, stop_id=1.930
#
# Group 4081: 4 trip_id  (kept: 1.104.11428898)
#   x 1.104.11430236
#   x 1.104.11571862
#   x 1.104.11572497
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:12:55, departure=05:12:55, stop_id=1.930
#   02. seq=2, arrival=05:15:33, departure=05:15:58, stop_id=1.932
#   03. seq=3, arrival=05:18:02, departure=05:18:27, stop_id=1.933
#   04. seq=4, arrival=05:20:08, departure=05:20:33, stop_id=1.934
#   05. seq=5, arrival=05:21:42, departure=05:22:07, stop_id=1.935
#   06. seq=6, arrival=05:23:51, departure=05:23:51, stop_id=1.936
#
# Group 4082: 4 trip_id  (kept: 1.301.1)
#   x 1.302.1
#   x 1.79.1
#   x 1.80.1
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=00:00:00, departure=00:00:00, stop_id=1.9901
#   02. seq=2, arrival=00:02:00, departure=00:02:00, stop_id=1.9902
#
# Group 4083: 4 trip_id  (kept: 1.301.2)
#   x 1.302.2
#   x 1.79.2
#   x 1.80.2
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=00:00:00, departure=00:00:00, stop_id=1.9902
#   02. seq=2, arrival=00:02:00, departure=00:02:00, stop_id=1.9901
#
# Group 4084: 4 trip_id  (kept: 1.94.11429205)
#   x 1.94.11430326
#   x 1.94.11571949
#   x 1.94.11572594
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.945
#   02. seq=2, arrival=05:01:37, departure=05:02:02, stop_id=1.944
#   03. seq=3, arrival=05:03:16, departure=05:03:41, stop_id=1.943
#   04. seq=4, arrival=05:04:52, departure=05:05:17, stop_id=1.942
#   05. seq=5, arrival=05:06:39, departure=05:07:04, stop_id=1.941
#   06. seq=6, arrival=05:08:11, departure=05:08:36, stop_id=1.940
#   07. seq=7, arrival=05:10:25, departure=05:10:50, stop_id=1.933
#   08. seq=8, arrival=05:12:53, departure=05:13:18, stop_id=1.932
#   09. seq=9, arrival=05:15:25, departure=05:15:25, stop_id=1.930
#
# Group 4085: 4 trip_id  (kept: 1.94.11429286)
#   x 1.94.11430395
#   x 1.94.11571965
#   x 1.94.11572610
# Common content (sorted by stop_sequence):
#   01. seq=1, arrival=05:00:00, departure=05:00:00, stop_id=1.930
#   02. seq=2, arrival=05:02:38, departure=05:03:03, stop_id=1.932
#   03. seq=3, arrival=05:05:07, departure=05:05:32, stop_id=1.933
#   04. seq=4, arrival=05:07:11, departure=05:07:36, stop_id=1.940
#   05. seq=5, arrival=05:08:45, departure=05:09:10, stop_id=1.941
#   06. seq=6, arrival=05:10:36, departure=05:11:01, stop_id=1.942
#   07. seq=7, arrival=05:12:11, departure=05:12:36, stop_id=1.943
#   08. seq=8, arrival=05:13:50, departure=05:14:15, stop_id=1.944
#   09. seq=9, arrival=05:16:01, departure=05:16:01, stop_id=1.945

# %%
# Read trip_ids_to_eliminate.txt and create stop_times_cleaned.txt
# keeping only rows whose trip_id is NOT in the elimination list.

def main():
    eliminate_path = os.path.join(BASE, "trip_ids_to_eliminate.txt")
    check_missing_files([STOP_TIMES_FILE, eliminate_path])

    # Load trip_id to eliminate
    with open(eliminate_path, 'r', encoding='utf-8') as f:
        to_eliminate: Set[str] = {line.strip() for line in f if line.strip()}

    print(f"Trip_id to eliminate: {len(to_eliminate)}")

    # Read stop_times and write cleaned version
    out_path = os.path.join(BASE, "stop_times_cleaned.txt")
    dialect = sniff_dialect(STOP_TIMES_FILE)

    total_rows = 0
    kept_rows = 0
    removed_rows = 0

    with open(STOP_TIMES_FILE, 'r', encoding='utf-8-sig', newline='') as fin, \
         open(out_path, 'w', encoding='utf-8', newline='') as fout:

        reader = csv.DictReader(fin, dialect=dialect)
        if reader.fieldnames is None:
            raise RuntimeError("stop_times.txt has no header.")

        writer = csv.DictWriter(fout, fieldnames=reader.fieldnames, dialect=dialect)
        writer.writeheader()

        for row in reader:
            total_rows += 1
            tid = row.get('trip_id', '').strip()
            if tid in to_eliminate:
                removed_rows += 1
            else:
                writer.writerow(row)
                kept_rows += 1

    print(f"Total rows in stop_times.txt: {total_rows}")
    print(f"Rows removed: {removed_rows}")
    print(f"Rows kept: {kept_rows}")
    print(f"Cleaned file saved to: {out_path}")

main()
# Out:
# Trip_id to eliminate: 4111
# Total rows in stop_times.txt: 1138586
# Rows removed: 78215
# Rows kept: 1060371
# Cleaned file saved to: c:\Users\Sarad\Escritorio\Mates\Cursos\Curs 2025-2026 (3r + 4t)\TFG\TFG\.src\gtfs\data\stop_times_cleaned.txt

# %%
# Check that no trip_id from trip_ids_to_eliminate.txt appears in stop_times_cleaned.txt

def main():
    eliminate_path = os.path.join(BASE, "trip_ids_to_eliminate.txt")
    cleaned_path = os.path.join(BASE, "stop_times_cleaned.txt")
    check_missing_files([eliminate_path, cleaned_path])

    # Load trip_id to eliminate
    with open(eliminate_path, 'r', encoding='utf-8') as f:
        to_eliminate: Set[str] = {line.strip() for line in f if line.strip()}

    # Scan cleaned file for any remaining eliminated trip_id
    found: Set[str] = set()
    total_rows = 0
    for r in read_dict_rows(cleaned_path):
        total_rows += 1
        tid = r.get('trip_id', '').strip()
        if tid in to_eliminate:
            found.add(tid)

    print(f"Trip_id to eliminate: {len(to_eliminate)}")
    print(f"Total rows in stop_times_cleaned.txt: {total_rows}")

    if not found:
        print("All correct: no eliminated trip_id found in stop_times_cleaned.txt.")
    else:
        print(f"ERROR: {len(found)} eliminated trip_id still present in stop_times_cleaned.txt:")
        for tid in sorted(found):
            print(f"- {tid}")

main()
# Out:
# Trip_id to eliminate: 4111
# Total rows in stop_times_cleaned.txt: 1060371
# All correct: no eliminated trip_id found in stop_times_cleaned.txt.

# %% [markdown]
# #### Schedule case

# %%
# Check in stop_times.txt (for stop_id == '1.433') that repeated times
# (departure_time) always correspond to different trip_id.
# Does not print all times, only a summary and problematic cases.

TARGET_STOP_ID='1.433'

def main():
    check_missing_files([STOP_TIMES_CLEANED_FILE])

    # time -> list of trip_ids (for this stop_id)
    time_to_trips: Dict[str, List[str]] = defaultdict(list)
    total_rows = 0
    matched_rows = 0

    for r in read_dict_rows(STOP_TIMES_CLEANED_FILE):
        total_rows += 1
        if r.get('stop_id', '') != TARGET_STOP_ID:
            continue
        dep = r.get('departure_time', '')
        tid = r.get('trip_id', '')
        if dep and tid:
            matched_rows += 1
            time_to_trips[dep].append(tid)

    unique_times = len(time_to_trips)
    repeated_times = {t: trips for t, trips in time_to_trips.items() if len(trips) >= 2}

    print(f"Total rows in stop_times_cleaned: {total_rows}")
    print(f"Target stop_id: {TARGET_STOP_ID}")
    print(f"Number of rows with departure_time and trip_id: {matched_rows}")
    print(f"\nUnique departure_time values: {unique_times}")
    print(f"Times appearing 2 or more times: {len(repeated_times)}")

    if not repeated_times:
        print("No repeated times for this stop_id.")
        return

    # Verify that for each repeated time, all trip_id are different
    violating = {}
    for t, trips in sorted(repeated_times.items()):
        counts = Counter(trips)
        # If any trip_id appears more than once for the same time, it's a violation
        bad = {trip_id: c for trip_id, c in counts.items() if c >= 2}
        if bad:
            violating[t] = bad

    if not violating:
        print("Correct: all repeated times correspond to different trip_id.")
    else:
        print("WARNING: repeated times found with the same trip_id (at least twice):")
        for t, bad_counts in violating.items():
            det = ", ".join([f"{trip_id} (x{c})" for trip_id, c in sorted(bad_counts.items())])
            print(f"- {t}: {det}")

# Execute
main()
# Out:
# Total rows in stop_times: 1060371
# Target stop_id: 1.433
# Number of rows with departure_time and trip_id: 1307
#
# Unique departure_time values: 1288
# Times appearing 2 or more times: 19
# Correct: all repeated times correspond to different trip_id.

# %%
# List departure_time for a specific trip_id, showing stop_name instead of stop_id
# Target trip_id: '1.101.11426484'


TRIP_ID = '1.4.11633035'

def main():
    check_missing_files([STOP_TIMES_FILE, STOPS_FILE])

    stop_names = load_stop_names(STOPS_FILE)

    rows: List[Tuple[int, str, str]] = []  # (stop_sequence, departure_time, stop_name)
    total_rows = 0
    for r in read_dict_rows(STOP_TIMES_FILE):
        total_rows += 1
        if r.get('trip_id', '') != TRIP_ID:
            continue
        dep = r.get('departure_time', '')
        sid = r.get('stop_id', '')
        sname = stop_names.get(sid, '(no name)')
        seq_str = r.get('stop_sequence', '')
        try:
            seq = int(seq_str)
        except Exception:
            # If it cannot be converted, place it at the end
            seq = 10**9
        rows.append((seq, dep, sname))

    rows.sort(key=lambda x: (x[0], x[1]))

    print(f"Total rows in stop_times: {total_rows}")
    print(f"Target trip_id: {TRIP_ID}")
    print(f"Number of rows found for the trip: {len(rows)}")

    if not rows:
        print("(No rows found in stop_times for this trip_id)")
        return

    print("List (sorted by stop_sequence) of departure_time — stop_name:")
    for i, (seq, dep, sname) in enumerate(rows, 1):
        dep_show = dep if dep else '(no departure_time)'
        print(f"{i:02d}. {dep_show} — {sname}")

main()
# Out:
# Total rows in stop_times: 1138586
# Target trip_id: 1.4.11633035
# Number of rows found for the trip: 22
# List (sorted by stop_sequence) of departure_time — stop_name:
# 01. 05:00:00 — Trinitat Nova
# 02. 05:01:30 — Via Júlia
# 03. 05:03:26 — Llucmajor
# 04. 05:06:37 — Maragall
# 05. 05:08:51 — Guinardó | Hospital de Sant Pau
# 06. 05:10:39 — Alfons X
# 07. 05:12:27 — Joanic
# 08. 05:14:12 — Verdaguer
# 09. 05:16:03 — Girona
# 10. 05:17:36 — Passeig de Gràcia
# 11. 05:19:24 — Urquinaona
# 12. 05:20:42 — Jaume I
# 13. 05:22:23 — Barceloneta
# 14. 05:24:00 — Ciutadella | Vila Olímpica
# 15. 05:26:34 — Bogatell
# 16. 05:27:56 — Llacuna
# 17. 05:29:30 — Poblenou
# 18. 05:30:55 — Selva de Mar
# 19. 05:32:06 — El Maresme | Fòrum
# 20. 05:33:20 — Besòs Mar
# 21. 05:34:45 — Besòs
# 22. 05:36:20 — La Pau

# %%
# List departure_time for a specific trip_id, showing stop_name instead of stop_id
# Target trip_id: '1.101.11426484'

TRIP_ID = '1.4.11633500'


def main():
    check_missing_files([STOP_TIMES_FILE, STOPS_FILE])

    stop_names = load_stop_names(STOPS_FILE)

    rows: List[Tuple[int, str, str]] = []  # (stop_sequence, departure_time, stop_name)
    total_rows = 0
    for r in read_dict_rows(STOP_TIMES_FILE):
        total_rows += 1
        if r.get('trip_id', '') != TRIP_ID:
            continue
        dep = r.get('departure_time', '')
        sid = r.get('stop_id', '')
        sname = stop_names.get(sid, '(no name)')
        seq_str = r.get('stop_sequence', '')
        try:
            seq = int(seq_str)
        except Exception:
            # If it cannot be converted, place it at the end
            seq = 10**9
        rows.append((seq, dep, sname))

    rows.sort(key=lambda x: (x[0], x[1]))

    print(f"Total rows in stop_times: {total_rows}")
    print(f"Target trip_id: {TRIP_ID}")
    print(f"Number of rows found for the trip: {len(rows)}")

    if not rows:
        print("(No rows found in stop_times for this trip_id)")
        return

    print("List (sorted by stop_sequence) of departure_time — stop_name:")
    for i, (seq, dep, sname) in enumerate(rows, 1):
        dep_show = dep if dep else '(no departure_time)'
        print(f"{i:02d}. {dep_show} — {sname}")

main()
# Out:
# Files totals a stop_times: 1138586
# trip_id objectiu: 1.4.11633500
# Nombre de files trobades per al trip: 22
# Llista (ordenada per stop_sequence) de departure_time — stop_name:
# 01. 05:00:00 — Trinitat Nova
# 02. 05:01:30 — Via Júlia
# 03. 05:03:26 — Llucmajor
# 04. 05:06:37 — Maragall
# 05. 05:08:51 — Guinardó | Hospital de Sant Pau
# 06. 05:10:39 — Alfons X
# 07. 05:12:27 — Joanic
# 08. 05:14:12 — Verdaguer
# 09. 05:16:03 — Girona
# 10. 05:17:36 — Passeig de Gràcia
# 11. 05:19:24 — Urquinaona
# 12. 05:20:42 — Jaume I
# 13. 05:22:23 — Barceloneta
# 14. 05:24:00 — Ciutadella | Vila Olímpica
# 15. 05:26:34 — Bogatell
# 16. 05:27:56 — Llacuna
# 17. 05:29:30 — Poblenou
# 18. 05:30:55 — Selva de Mar
# 19. 05:32:06 — El Maresme | Fòrum
# 20. 05:33:20 — Besòs Mar
# 21. 05:34:45 — Besòs
# 22. 05:36:20 — La Pau

# %%
# List departure_time for a specific trip_id, showing stop_name instead of stop_id
# Target trip_id: '1.101.11426484'

TRIP_ID = '1.4.11644917'

def main():
    check_missing_files([STOP_TIMES_FILE, STOPS_FILE])

    stop_names = load_stop_names(STOPS_FILE)

    rows: List[Tuple[int, str, str]] = []  # (stop_sequence, departure_time, stop_name)
    total_rows = 0
    for r in read_dict_rows(STOP_TIMES_FILE):
        total_rows += 1
        if r.get('trip_id', '') != TRIP_ID:
            continue
        dep = r.get('departure_time', '')
        sid = r.get('stop_id', '')
        sname = stop_names.get(sid, '(no name)')
        seq_str = r.get('stop_sequence', '')
        try:
            seq = int(seq_str)
        except Exception:
            # If it cannot be converted, place it at the end
            seq = 10**9
        rows.append((seq, dep, sname))

    rows.sort(key=lambda x: (x[0], x[1]))

    print(f"Total rows in stop_times: {total_rows}")
    print(f"Target trip_id: {TRIP_ID}")
    print(f"Number of rows found for the trip: {len(rows)}")

    if not rows:
        print("(No rows found in stop_times for this trip_id)")
        return

    print("List (sorted by stop_sequence) of departure_time — stop_name:")
    for i, (seq, dep, sname) in enumerate(rows, 1):
        dep_show = dep if dep else '(no departure_time)'
        print(f"{i:02d}. {dep_show} — {sname}")

main()
# Out:
# Files totals a stop_times: 1138586
# trip_id objectiu: 1.4.11644917
# Nombre de files trobades per al trip: 22
# Llista (ordenada per stop_sequence) de departure_time — stop_name:
# 01. 05:00:00 — Trinitat Nova
# 02. 05:01:30 — Via Júlia
# 03. 05:03:16 — Llucmajor
# 04. 05:06:27 — Maragall
# 05. 05:08:31 — Guinardó | Hospital de Sant Pau
# 06. 05:10:19 — Alfons X
# 07. 05:11:57 — Joanic
# 08. 05:13:42 — Verdaguer
# 09. 05:15:23 — Girona
# 10. 05:16:56 — Passeig de Gràcia
# 11. 05:18:34 — Urquinaona
# 12. 05:19:52 — Jaume I
# 13. 05:21:23 — Barceloneta
# 14. 05:23:00 — Ciutadella | Vila Olímpica
# 15. 05:25:24 — Bogatell
# 16. 05:26:46 — Llacuna
# 17. 05:28:10 — Poblenou
# 18. 05:29:35 — Selva de Mar
# 19. 05:30:46 — El Maresme | Fòrum
# 20. 05:32:00 — Besòs Mar
# 21. 05:33:25 — Besòs
# 22. 05:35:00 — La Pau

# %% [markdown]
# #### Does stop_sequence increment by one?

# %% [markdown]
# Goal: check whether stop_sequence in stop_times.txt increments by one. To do this, we look at all
# trip_id from trips.txt. For each one, we go to stop_times.txt and look at the rows with that
# trip_id. We aggregate only the stop_sequence values per trip_id (without storing the full row) and check
# whether they increment by one. Optimized: we read stop_times once and aggregate by trip_id.
# Parallel validation per trip with ThreadPoolExecutor to reduce total time.

# %%
def main():
    check_missing_files([STOP_TIMES_FILE, TRIPS_FILE])

    # trip_id of interest (filtered by prefix '1.')
    trip_ids = load_trip_ids(TRIPS_FILE)
    trip_ids = sorted(ids for ids in trip_ids if ids.startswith("1."))
    trip_id_set = set(trip_ids)

    print(f"Unique trip_id in trips (prefix '1.'): {len(trip_ids)}")

    # Build: trip_id -> set of stop_sequence (no duplicates), in a single pass over stop_times
    seq_by_trip: Dict[str, Set[int]] = defaultdict(set)
    for r in read_dict_rows(STOP_TIMES_FILE):
        tid = r.get('trip_id', '')
        if tid not in trip_id_set:
            continue
        seq_str = r.get('stop_sequence', '')
        try:
            seq = int(seq_str)
        except Exception:
            # Ignore non-numeric or empty values
            continue
        seq_by_trip[tid].add(seq)

    # Final map: trip_id -> sorted list of stop_sequence (no duplicates)
    dict_seq: Dict[str, List[int]] = {}
    for trip_id in trip_ids:
        dict_seq[trip_id] = sorted(seq_by_trip.get(trip_id, set()))

    # Parallel validation
    max_workers = min(8, (os.cpu_count() or 4))
    violations_total = 0
    with ThreadPoolExecutor(max_workers=max_workers) as ex:
        futures = {
            ex.submit(check_trip, trip_id, dict_seq[trip_id]): trip_id for trip_id in trip_ids
        }
        for fut in as_completed(futures):
            msgs = fut.result()
            violations_total += len(msgs)
            for m in msgs:
                print(m)

    if violations_total == 0:
        print("Correct: all trips have stop_sequence that increments by one.")
    else:
        print(f"Total violations detected: {violations_total}")

main()
# Out:
# trip_id únics a trips (prefix '1.'): 15088
# Correcte: tots els trips tenen stop_sequence que incrementa d'un en un.

# %% [markdown]
# ### Check that trips with trip_headsign Aeroport T1 don't only have 1 as direction_id

# %%
# Search for trip_id with trip_headsign == 'Aeroport T1' and direction_id == 0 in trips.txt

def main():
    check_missing_files([TRIPS_FILE])

    matches: List[str] = []
    total = 0
    for r in read_dict_rows(TRIPS_FILE):
        total += 1
        headsign = r.get('trip_headsign', '')
        direction = r.get('direction_id', '')
        if headsign == 'Aeroport T1' and direction == '0':
            tid = r.get('trip_id', '')
            if tid:
                matches.append(tid)

    print(f"Total rows in trips: {total}")
    if not matches:
        print("No trip found with trip_headsign='Aeroport T1' and direction_id=0.")
    else:
        print(f"Found {len(matches)} trip_id with trip_headsign='Aeroport T1' and direction_id=0:")
        for tid in sorted(matches):
            print(f"- {tid}")

main()
# Out:
# Files totals a trips: 48987
# No s'ha trobat cap trip amb trip_headsign='Aeroport T1' i direction_id=0.

# %%
# Count how many unique trip_id in trips.txt have route_id == '1.4.1' per direction_id (0 and 1)

TARGET_ROUTE = '1.4.1'

def main():
    check_missing_files([TRIPS_FILE])

    trips_dir0: Set[str] = set()
    trips_dir1: Set[str] = set()
    trips_other: Set[str] = set()

    total_rows = 0
    for r in read_dict_rows(TRIPS_FILE):
        total_rows += 1
        rid = get_first_nonempty(r, 'route_id', 'routes_id')
        if rid != TARGET_ROUTE:
            continue
        tid = r.get('trip_id', '').strip()
        d = r.get('direction_id', '').strip()
        if not tid:
            continue
        if d == '0':
            trips_dir0.add(tid)
        elif d == '1':
            trips_dir1.add(tid)
        else:
            trips_other.add(tid)

    print(f"Total rows in trips: {total_rows}")
    print(f"Target route_id: {TARGET_ROUTE}")
    print(f"\nResults (unique trip_id):")
    print(f"direction_id = 0: {len(trips_dir0)}")
    print(f"direction_id = 1: {len(trips_dir1)}")
    if trips_other:
        print(f"other/missing direction_id: {len(trips_other)}")

main()
# Out:
# Rows totals a trips: 48987
# route_id objectiu: 1.4.1
#
# Resultats (trip_id únics):
# direction_id = 0: 872
# direction_id = 1: 872
